# %%
#single_image = r"C:\Users\danie\Desktop\tiny rainbow.jpg"
image_folder = r"C:\Users\midyr\Downloads\colorwheels"
image_pathway = r"C:\Users\midyr\Downloads\colorwheels\MicrosoftTeams-image.png"

TOO_SMALL = 20
SMALL = 500000
MEDIUM = 1200000
LARGE = 2100000
    
X_train = []
Y_train = []
counter = 1
    
height = 128
width = 128

epochs = 10 
batch_size = 1 
total_images = 1

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import skimage
import glob
import cv2
import pandas as pd

from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, UpSampling2D, InputLayer
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage import data, io, color
from skimage.io import imread, imshow, imsave
from pathlib import Path

from sklearn.decomposition import PCA

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
def shape(img):
    size = 0
    resolution = img.shape[0] * img.shape[1]
    if resolution <= TOO_SMALL:
        size = 0
    elif resolution <= SMALL:
        size = 1
    elif resolution <= MEDIUM:
        size = 2
    elif resolution <= LARGE:
        size = 3
    else:
        size = 6
    return size

# %%
def create_dataframe(image_folder):
    images = Path(image_folder).glob('*.png') #.jpg

    list_of_files = []
    for image in images:
        list_of_files.append(str(image))

    df = pd. DataFrame(list_of_files, columns = ["image_path"])
    df_length = len(df.index)
    
    print("processing", df_length, "photos for training")
    
    height_list= []
    width_list = []
    resolution = []
    
    for image_path in df['image_path']:
        img = cv2.imread(str(image_path))
        height_list.append(img.shape[0])
        width_list.append(img.shape[1])
        
    df["height"] = height_list
    df["width"] = width_list
    df["resolution"] = df["height"] * df["width"]
    
    df = df[df.resolution < LARGE]
    
    ll = df_length - len(df.index)
    print("dropped ", ll, "photos because they were too large to process")
    
    df = df[df.resolution > TOO_SMALL]
    
    ss = df_length - len(df.index) - ll
    print("dropped ", ss, "photos because they were too small to process")
    df.head()
    
    return df

# %%
def pca_rgb(imgBGR, size): #imgRGB, size
    b,g,r = cv2.split(imgBGR)
    list_channels = [b,g,r]
    
    #check size first
    if size ==1:
        inverted_img = []
        for c in list_channels:            
            pca = PCA(n_components = 100)
            transformed = pca.fit_transform(c/255) #r_scaled
            inverted = pca.inverse_transform(transformed)
            inverted_img.append(inverted)
        
        tuple(inverted_img)
        RGB_compressed = cv2.merge(inverted_img)    

    elif size == 2:
        inverted_img = []
        for c in list_channels:            
            pca = PCA(n_components = 300)
            transformed = pca.fit_transform(c/255) #r_scaled
            inverted = pca.inverse_transform(transformed)
            inverted_img.append(inverted)
        
        tuple(inverted_img)
        RGB_compressed = cv2.merge(inverted_img)
    else:
        inverted_img = []
        for c in list_channels:            
            pca = PCA(n_components = 500)
            transformed = pca.fit_transform(c/255) #r_scaled
            inverted = pca.inverse_transform(transformed)
            inverted_img.append(inverted)
        
        tuple(inverted_img)
        RGB_compressed = cv2.merge(inverted_img)
        
    RGB_compressed = np.float32(RGB_compressed)
    print("PCA SHAPE",np.min(RGB_compressed),np.max(RGB_compressed))    
    return RGB_compressed

# %%
def rgb_pad(image):
    
    img_height = image.shape[0]
    print(height)
    img_width = image.shape[1]
    print(width)
    
    WHITE = [255,255,255] #[255,255,255]  1, 1, 1
    
    if img_height % 2 == 0:
        top = int((height - img_height)/ 2)
        bottom = int((height - img_height)/ 2)
    else: 
        top = int((height - (img_height-1))/ 2)
        bottom = int(((height - (img_height-1))/ 2)-1)

    if img_width % 2 == 0:
        left = int((width - img_width)/ 2)
        right = int((width - img_width)/ 2)
    else: 
        left = int((width - (img_width-1))/ 2)
        right = int(((width - (img_width-1))/2)-1)
    
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT,value=WHITE)
    print(image.shape)
    print(np.min(image),np.max(image))

    return image

# %%
def prep_img(img_path):
    imgRGB = img_to_array(load_img(img_path))
    imgRGB = np.array(imgRGB, dtype=float)
    print('Padded:', np.min(imgRGB), np.max(imgRGB))



    image_size_category = shape(imgRGB) 
    if image_size_category <1:
        raise Exception("Your image is too small to be used")
    elif image_size_category >4:
        raise Exception("Your image is too big to be used")

    if PCA_YN == "yes":
        RGB_compressed = pca_rgb(imgRGB, image_size_category)
        RGB_compressed = np.clip(RGB_compressed,0,1) * 255
        print("PCA ran")
    else:
        RGB_compressed = imgRGB
        print("PCA did not run")


    
    padded_image = rgb_pad(RGB_compressed)

    print('Padded:', np.min(padded_image), np.max(padded_image))
    X_LAB = color.rgb2lab(1.0/255*padded_image)[:,:,0] #1.0/255*padded_image
    print('X_LAB:', np.min(X_LAB), np.max(X_LAB))
    Y_LAB1 = color.rgb2lab(1.0/255*padded_image)[:,:,1:] #1.0/255*padded_image
    print('Y_LAB1:', np.min(Y_LAB1), np.max(Y_LAB1))
    Y_LAB = Y_LAB1 / 128
    print('Y_LAB:', np.min(Y_LAB), np.max(Y_LAB))


    print(X_LAB.shape)
    X = X_LAB.reshape(1, height, width, 1) #comment out when show predicted
    Y = Y_LAB.reshape(1, height, width, 2) #comment out when show predicted
    
    print("image processed")

    return Y, X

# %%
def prep_dataframe(df):
    for index, row in df.iterrows():
        Y, X = prep_img(row["image_path"])
        Y_train.append(Y)
        X_train.append(X)

# %%
PCA_YN = "no"

#prep_image(single_image)

df = create_dataframe(image_folder)
prep_dataframe(df)
# Out:
# processing 3 photos for training
# dropped  0 photos because they were too large to process
# dropped  0 photos because they were too small to process
# Padded: 0.0 255.0
# PCA did not run
# 128
# 128
# (128, 128, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 21.73390280398273 100.0
# Y_LAB1: -82.93441399808646 93.91007169334684
# Y_LAB: -0.6479251093600504 0.7336724351042722
# (128, 128)
# image processed
# Padded: 0.0 255.0
# PCA did not run
# 128
# 128
# (128, 128, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 21.73390280398273 100.0
# Y_LAB1: -82.93441399808646 93.91007169334684
# Y_LAB: -0.6479251093600504 0.7336724351042722
# (128, 128)
# image processed
# Padded: 0.0 255.0
# PCA did not run
# 128
# 128
# (128, 128, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 21.73390280398273 100.0
# Y_LAB1: -82.93441399808646 93.91007169334684
# Y_LAB: -0.6479251093600504 0.7336724351042722
# (128, 128)
# image processed

# %% [markdown]
# # MODEL

# %%
BATCH_SIZE = 10
LEARNING_RATE = 0.001
EPOCHS = 100
KERNEL_SIZE = 3
NUM_CLASSES = 2 #313
IMAGE_WIDTH = 128 #128
IMAGE_HEIGHT = 128 #128
SIGMA = 5

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, UpSampling2D



def mode():

    model = tf.keras.Sequential([
    Conv2D(32, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(32, kernel_size=KERNEL_SIZE, activation='relu', padding='same', strides=(2, 2)),
    BatchNormalization(),

    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same', strides=(2, 2)),
    BatchNormalization(),

    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same', strides=(2, 2)),
    BatchNormalization(),

    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    BatchNormalization(),

    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    BatchNormalization(),

    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    BatchNormalization(),

    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    BatchNormalization(),

    UpSampling2D(size=(2, 2)),
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    BatchNormalization(),

    Conv2D(NUM_CLASSES, kernel_size=1, padding='same'), UpSampling2D(size=(4, 4))
        ])
    
    model.compile(optimizer ="adam", loss = "CategoricalCrossentropy", metrics = ["accuracy"])
    
    return model

# %%
model = mode()

# %%
train_data = tf.data.Dataset.from_tensor_slices((X_train, Y_train))

# %%
len(X_train)
# Out:
# 3

# %%
history = model.fit(train_data, batch_size = batch_size, epochs = EPOCHS, verbose = 2)  # add validation_split = 0.2
# Out:
# Epoch 1/100
# 3/3 - 0s - loss: -8.8756e-01 - accuracy: 0.2485 - 366ms/epoch - 122ms/step
# Epoch 2/100
# 3/3 - 0s - loss: -7.3096e-01 - accuracy: 0.2168 - 380ms/epoch - 127ms/step
# Epoch 3/100
# 3/3 - 0s - loss: -2.3219e-01 - accuracy: 0.2018 - 430ms/epoch - 143ms/step
# Epoch 4/100
# 3/3 - 0s - loss: -2.8094e-01 - accuracy: 0.2630 - 469ms/epoch - 156ms/step
# Epoch 5/100
# 3/3 - 0s - loss: -2.1962e-01 - accuracy: 0.3079 - 390ms/epoch - 130ms/step
# Epoch 6/100
# 3/3 - 0s - loss: -4.2391e-01 - accuracy: 0.3399 - 412ms/epoch - 137ms/step
# Epoch 7/100
# 3/3 - 0s - loss: -6.0950e-01 - accuracy: 0.3725 - 390ms/epoch - 130ms/step
# Epoch 8/100
# 3/3 - 0s - loss: -3.8158e-01 - accuracy: 0.3907 - 358ms/epoch - 119ms/step
# Epoch 9/100
# 3/3 - 0s - loss: -5.5017e-01 - accuracy: 0.3933 - 397ms/epoch - 132ms/step
# Epoch 10/100
# 3/3 - 0s - loss: -6.0795e-01 - accuracy: 0.4404 - 496ms/epoch - 165ms/step
# Epoch 11/100
# 3/3 - 0s - loss: 0.0182 - accuracy: 0.4446 - 416ms/epoch - 139ms/step
# Epoch 12/100
# 3/3 - 0s - loss: 1.1331 - accuracy: 0.5595 - 455ms/epoch - 152ms/step
# Epoch 13/100
# 3/3 - 0s - loss: 0.3820 - accuracy: 0.4924 - 382ms/epoch - 127ms/step
# Epoch 14/100
# 3/3 - 0s - loss: 0.4264 - accuracy: 0.4114 - 370ms/epoch - 123ms/step
# Epoch 15/100
# 3/3 - 0s - loss: 0.3274 - accuracy: 0.5549 - 386ms/epoch - 129ms/step
# Epoch 16/100
# 3/3 - 0s - loss: 0.5899 - accuracy: 0.6794 - 377ms/epoch - 126ms/step
# Epoch 17/100
# 3/3 - 0s - loss: 0.7886 - accuracy: 0.6143 - 410ms/epoch - 137ms/step
# Epoch 18/100
# 3/3 - 0s - loss: 1.0106 - accuracy: 0.4791 - 369ms/epoch - 123ms/step
# Epoch 19/100
# 3/3 - 0s - loss: 0.7467 - accuracy: 0.3422 - 368ms/epoch - 123ms/step
# Epoch 20/100
# 3/3 - 0s - loss: 0.8725 - accuracy: 0.3842 - 375ms/epoch - 125ms/step
# Epoch 21/100
# 3/3 - 0s - loss: 1.0778 - accuracy: 0.4314 - 387ms/epoch - 129ms/step
# Epoch 22/100
# 3/3 - 0s - loss: 0.7236 - accuracy: 0.4296 - 372ms/epoch - 124ms/step
# Epoch 23/100
# 3/3 - 0s - loss: 0.0599 - accuracy: 0.3772 - 370ms/epoch - 123ms/step
# Epoch 24/100
# 3/3 - 0s - loss: -9.3903e-02 - accuracy: 0.3899 - 382ms/epoch - 127ms/step
# Epoch 25/100
# 3/3 - 0s - loss: -9.6813e-02 - accuracy: 0.4113 - 374ms/epoch - 125ms/step
# Epoch 26/100
# 3/3 - 0s - loss: -1.8792e-01 - accuracy: 0.4245 - 374ms/epoch - 125ms/step
# Epoch 27/100
# 3/3 - 0s - loss: -2.8880e-01 - accuracy: 0.4388 - 374ms/epoch - 125ms/step
# Epoch 28/100
# 3/3 - 0s - loss: -2.6296e-01 - accuracy: 0.4449 - 382ms/epoch - 127ms/step
# Epoch 29/100
# 3/3 - 0s - loss: -2.6059e-01 - accuracy: 0.4719 - 374ms/epoch - 125ms/step
# Epoch 30/100
# 3/3 - 0s - loss: -3.7260e-01 - accuracy: 0.4995 - 373ms/epoch - 124ms/step
# Epoch 31/100
# 3/3 - 0s - loss: -3.6597e-01 - accuracy: 0.4928 - 376ms/epoch - 125ms/step
# Epoch 32/100
# 3/3 - 0s - loss: -3.7533e-01 - accuracy: 0.4646 - 384ms/epoch - 128ms/step
# Epoch 33/100
# 3/3 - 0s - loss: -3.3310e-01 - accuracy: 0.4446 - 387ms/epoch - 129ms/step
# Epoch 34/100
# 3/3 - 0s - loss: -3.6186e-01 - accuracy: 0.4183 - 397ms/epoch - 132ms/step
# Epoch 35/100
# 3/3 - 0s - loss: -4.6463e-01 - accuracy: 0.3980 - 396ms/epoch - 132ms/step
# Epoch 36/100
# 3/3 - 0s - loss: -3.9818e-01 - accuracy: 0.3833 - 392ms/epoch - 131ms/step
# Epoch 37/100
# 3/3 - 0s - loss: -3.6746e-01 - accuracy: 0.3680 - 384ms/epoch - 128ms/step
# Epoch 38/100
# 3/3 - 0s - loss: -2.2254e-01 - accuracy: 0.3498 - 381ms/epoch - 127ms/step
# Epoch 39/100
# 3/3 - 0s - loss: 0.3929 - accuracy: 0.3337 - 372ms/epoch - 124ms/step
# Epoch 40/100
# 3/3 - 0s - loss: -1.8006e-01 - accuracy: 0.2893 - 374ms/epoch - 125ms/step
# Epoch 41/100
# 3/3 - 0s - loss: -4.4612e-02 - accuracy: 0.2802 - 384ms/epoch - 128ms/step
# Epoch 42/100
# 3/3 - 0s - loss: 0.0344 - accuracy: 0.2838 - 426ms/epoch - 142ms/step
# Epoch 43/100
# 3/3 - 0s - loss: 0.0416 - accuracy: 0.3281 - 465ms/epoch - 155ms/step
# Epoch 44/100
# 3/3 - 1s - loss: 0.1584 - accuracy: 0.4029 - 509ms/epoch - 170ms/step
# Epoch 45/100
# 3/3 - 0s - loss: 0.2566 - accuracy: 0.3997 - 462ms/epoch - 154ms/step
# Epoch 46/100
# 3/3 - 0s - loss: 0.2879 - accuracy: 0.3928 - 484ms/epoch - 161ms/step
# Epoch 47/100
# 3/3 - 0s - loss: 0.2484 - accuracy: 0.3853 - 387ms/epoch - 129ms/step
# Epoch 48/100
# 3/3 - 0s - loss: 0.1642 - accuracy: 0.3863 - 379ms/epoch - 126ms/step
# Epoch 49/100
# 3/3 - 0s - loss: 0.1951 - accuracy: 0.3695 - 369ms/epoch - 123ms/step
# Epoch 50/100
# 3/3 - 0s - loss: 0.1807 - accuracy: 0.3479 - 372ms/epoch - 124ms/step
# Epoch 51/100
# 3/3 - 0s - loss: -5.9898e-02 - accuracy: 0.3444 - 395ms/epoch - 132ms/step
# Epoch 52/100
# 3/3 - 0s - loss: -1.5998e-01 - accuracy: 0.3586 - 389ms/epoch - 130ms/step
# Epoch 53/100
# 3/3 - 0s - loss: -2.4660e-01 - accuracy: 0.3833 - 388ms/epoch - 129ms/step
# Epoch 54/100
# 3/3 - 0s - loss: -3.0816e-01 - accuracy: 0.3986 - 376ms/epoch - 125ms/step
# Epoch 55/100
# 3/3 - 0s - loss: -2.9784e-01 - accuracy: 0.4038 - 373ms/epoch - 124ms/step
# Epoch 56/100
# 3/3 - 0s - loss: -3.4674e-01 - accuracy: 0.4056 - 455ms/epoch - 152ms/step
# Epoch 57/100
# 3/3 - 1s - loss: -4.3670e-01 - accuracy: 0.4143 - 522ms/epoch - 174ms/step
# Epoch 58/100
# 3/3 - 0s - loss: -5.5136e-01 - accuracy: 0.4210 - 464ms/epoch - 155ms/step
# Epoch 59/100
# 3/3 - 0s - loss: -6.7253e-01 - accuracy: 0.4119 - 483ms/epoch - 161ms/step
# Epoch 60/100
# 3/3 - 0s - loss: -7.7310e-01 - accuracy: 0.3619 - 444ms/epoch - 148ms/step
# Epoch 61/100
# 3/3 - 1s - loss: -5.9066e-01 - accuracy: 0.3647 - 514ms/epoch - 171ms/step
# Epoch 62/100
# 3/3 - 0s - loss: 0.3687 - accuracy: 0.3767 - 476ms/epoch - 159ms/step
# Epoch 63/100
# 3/3 - 0s - loss: 0.9166 - accuracy: 0.3827 - 447ms/epoch - 149ms/step
# Epoch 64/100
# 3/3 - 0s - loss: 1.1252 - accuracy: 0.3885 - 468ms/epoch - 156ms/step
# Epoch 65/100
# 3/3 - 0s - loss: 1.1493 - accuracy: 0.4265 - 453ms/epoch - 151ms/step
# Epoch 66/100
# 3/3 - 0s - loss: 0.6482 - accuracy: 0.4673 - 453ms/epoch - 151ms/step
# Epoch 67/100
# 3/3 - 0s - loss: -1.7325e-01 - accuracy: 0.4357 - 456ms/epoch - 152ms/step
# Epoch 68/100
# 3/3 - 0s - loss: 0.2856 - accuracy: 0.5545 - 395ms/epoch - 132ms/step
# Epoch 69/100
# 3/3 - 0s - loss: 0.0273 - accuracy: 0.5846 - 492ms/epoch - 164ms/step
# Epoch 70/100
# 3/3 - 0s - loss: -1.8512e-01 - accuracy: 0.5841 - 462ms/epoch - 154ms/step
# Epoch 71/100
# 3/3 - 0s - loss: -1.2696e-01 - accuracy: 0.5603 - 387ms/epoch - 129ms/step
# Epoch 72/100
# 3/3 - 0s - loss: -2.4425e-02 - accuracy: 0.5405 - 456ms/epoch - 152ms/step
# Epoch 73/100
# 3/3 - 0s - loss: 0.1089 - accuracy: 0.5309 - 416ms/epoch - 139ms/step
# Epoch 74/100
# 3/3 - 0s - loss: 0.2421 - accuracy: 0.5331 - 378ms/epoch - 126ms/step
# Epoch 75/100
# 3/3 - 0s - loss: 0.4329 - accuracy: 0.5374 - 373ms/epoch - 124ms/step
# Epoch 76/100
# 3/3 - 0s - loss: 0.5501 - accuracy: 0.5387 - 399ms/epoch - 133ms/step
# Epoch 77/100
# 3/3 - 0s - loss: 0.4928 - accuracy: 0.5907 - 384ms/epoch - 128ms/step
# Epoch 78/100
# 3/3 - 0s - loss: 0.3692 - accuracy: 0.6539 - 383ms/epoch - 128ms/step
# Epoch 79/100
# 3/3 - 0s - loss: 0.2188 - accuracy: 0.6991 - 419ms/epoch - 140ms/step
# Epoch 80/100
# 3/3 - 0s - loss: 0.1952 - accuracy: 0.7085 - 448ms/epoch - 149ms/step
# Epoch 81/100
# 3/3 - 0s - loss: 0.1411 - accuracy: 0.6816 - 420ms/epoch - 140ms/step
# Epoch 82/100
# 3/3 - 0s - loss: -9.7737e-02 - accuracy: 0.6450 - 437ms/epoch - 146ms/step
# Epoch 83/100
# 3/3 - 0s - loss: -3.7578e-01 - accuracy: 0.6280 - 398ms/epoch - 133ms/step
# Epoch 84/100
# 3/3 - 0s - loss: -3.9544e-01 - accuracy: 0.6334 - 441ms/epoch - 147ms/step
# Epoch 85/100
# 3/3 - 0s - loss: -3.3501e-01 - accuracy: 0.6198 - 474ms/epoch - 158ms/step
# Epoch 86/100
# 3/3 - 0s - loss: -2.8107e-01 - accuracy: 0.6181 - 438ms/epoch - 146ms/step
# Epoch 87/100
# 3/3 - 0s - loss: -2.1336e-01 - accuracy: 0.6237 - 470ms/epoch - 157ms/step
# Epoch 88/100
# 3/3 - 0s - loss: -2.4014e-01 - accuracy: 0.6286 - 386ms/epoch - 129ms/step
# Epoch 89/100
# 3/3 - 0s - loss: -3.4192e-01 - accuracy: 0.6328 - 397ms/epoch - 132ms/step
# Epoch 90/100
# 3/3 - 0s - loss: -4.4434e-01 - accuracy: 0.6343 - 390ms/epoch - 130ms/step
# Epoch 91/100
# 3/3 - 0s - loss: -5.4516e-01 - accuracy: 0.6316 - 372ms/epoch - 124ms/step
# Epoch 92/100
# 3/3 - 0s - loss: -5.5774e-01 - accuracy: 0.6283 - 377ms/epoch - 126ms/step
# Epoch 93/100
# 3/3 - 0s - loss: -3.1562e-01 - accuracy: 0.6013 - 384ms/epoch - 128ms/step
# Epoch 94/100
# 3/3 - 0s - loss: -1.5941e-01 - accuracy: 0.5789 - 405ms/epoch - 135ms/step
# Epoch 95/100
# 3/3 - 0s - loss: -8.2212e-02 - accuracy: 0.5741 - 484ms/epoch - 161ms/step
# Epoch 96/100
# 3/3 - 0s - loss: -7.2434e-02 - accuracy: 0.5832 - 477ms/epoch - 159ms/step
# Epoch 97/100
# 3/3 - 0s - loss: -9.5933e-02 - accuracy: 0.5827 - 422ms/epoch - 141ms/step
# Epoch 98/100
# 3/3 - 0s - loss: -1.1857e-01 - accuracy: 0.5817 - 428ms/epoch - 143ms/step
# Epoch 99/100
# 3/3 - 0s - loss: -1.8565e-01 - accuracy: 0.5555 - 455ms/epoch - 152ms/step
# Epoch 100/100
# 3/3 - 0s - loss: -2.5218e-01 - accuracy: 0.5162 - 383ms/epoch - 128ms/step

# %%
#filename = 'Singular_Model'
#model2.save(filename)
#saved_model = load_model("Singular Model")

# %% [markdown]
# # PREDICTION

# %%
def get_photo(image):
    prep_color, prep_bw = prep_img(image_pathway)
    test_predict = model.predict(prep_bw)
    
    print(np.min(test_predict[:,:,1]), np.max(test_predict[:,:,1]))
    
    test_predict_reshaped= test_predict[0,:,:,:]
    test_predict_reshaped = test_predict_reshaped*128
    BW_reshaped  = prep_bw[0,:,:,:]
    
    print(np.min(test_predict_reshaped[:,:,1]), np.max(test_predict_reshaped[:,:,1]))
    
    test_merged_LAB = np.dstack((BW_reshaped, test_predict_reshaped))
    test_merged_rgb = color.lab2rgb(test_merged_LAB)
    
    plt.figure(figsize=(15, 15))
    plt.imshow(test_merged_rgb)

# %%
get_photo(image_pathway)
# Out:
# Padded: 0.0 255.0
# PCA did not run
# 128
# 128
# (128, 128, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 21.73390280398273 100.0
# Y_LAB1: -82.93441399808646 93.91007169334684
# Y_LAB: -0.6479251093600504 0.7336724351042722
# (128, 128)
# image processed
# -12.290153 11.821621
# -1089.1005 12350.763
# C:\Users\midyr\anaconda3\lib\site-packages\skimage\color\colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 10080 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
