# %%
image_folder = r"C:\Users\midyr\Downloads\colorwheels"

TOO_SMALL = 20
SMALL = 500000
MEDIUM = 1200000
LARGE = 2100000
    
X_train = []
Y_train = []
counter = 1
    
height = 256
width = 256

total_images = 1

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import skimage
import glob
import cv2
import pandas as pd
from tensorflow.keras import callbacks
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, UpSampling2D, InputLayer, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage import data, io, color
from skimage.io import imread, imshow, imsave
from pathlib import Path

from sklearn.decomposition import PCA

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
def shape(img):
    size = 0
    resolution = img.shape[0] * img.shape[1]
    if resolution <= TOO_SMALL:
        size = 0
    elif resolution <= SMALL:
        size = 1
    elif resolution <= MEDIUM:
        size = 2
    elif resolution <= LARGE:
        size = 3
    else:
        size = 6
    return size

# %%
def create_dataframe(image_folder):
    images = Path(image_folder).glob('*.jpg') #.png

    list_of_files = []
    for image in images:
        list_of_files.append(str(image))

    df = pd. DataFrame(list_of_files, columns = ["image_path"])
    df_length = len(df.index)
    
    print("processing", df_length, "photos for training")
    
    height_list= []
    width_list = []
    resolution = []
    
    for image_path in df['image_path']:
        img = cv2.imread(str(image_path))
        height_list.append(img.shape[0])
        width_list.append(img.shape[1])
        
    df["height"] = height_list
    df["width"] = width_list
    df["resolution"] = df["height"] * df["width"]
    
    df = df[df.resolution < LARGE]
    
    ll = df_length - len(df.index)
    print("dropped ", ll, "photos because they were too large to process")
    
    df = df[df.resolution > TOO_SMALL]
    
    ss = df_length - len(df.index) - ll
    print("dropped ", ss, "photos because they were too small to process")
    df.head()
    
    return df

# %%
def pca_rgb(imgBGR, size): #imgRGB, size
    b,g,r = cv2.split(imgBGR)
    list_channels = [b,g,r]
    
    #check size first
    if size ==1:
        inverted_img = []
        for c in list_channels:            
            pca = PCA(n_components = 100)
            transformed = pca.fit_transform(c/255) #r_scaled
            inverted = pca.inverse_transform(transformed)
            inverted_img.append(inverted)
        
        tuple(inverted_img)
        RGB_compressed = cv2.merge(inverted_img)    

    elif size == 2:
        inverted_img = []
        for c in list_channels:            
            pca = PCA(n_components = 300)
            transformed = pca.fit_transform(c/255) #r_scaled
            inverted = pca.inverse_transform(transformed)
            inverted_img.append(inverted)
        
        tuple(inverted_img)
        RGB_compressed = cv2.merge(inverted_img)
    else:
        inverted_img = []
        for c in list_channels:            
            pca = PCA(n_components = 500)
            transformed = pca.fit_transform(c/255) #r_scaled
            inverted = pca.inverse_transform(transformed)
            inverted_img.append(inverted)
        
        tuple(inverted_img)
        RGB_compressed = cv2.merge(inverted_img)
        
    RGB_compressed = np.float32(RGB_compressed)
    print("PCA SHAPE",np.min(RGB_compressed),np.max(RGB_compressed))    
    return RGB_compressed

# %%
def rgb_pad(image):
    
    img_height = image.shape[0]
    print(height)
    img_width = image.shape[1]
    print(width)
    
    WHITE = [255,255,255] #[255,255,255]  1, 1, 1
    
    if img_height % 2 == 0:
        top = int((height - img_height)/ 2)
        bottom = int((height - img_height)/ 2)
    else: 
        top = int((height - (img_height-1))/ 2)
        bottom = int(((height - (img_height-1))/ 2)-1)

    if img_width % 2 == 0:
        left = int((width - img_width)/ 2)
        right = int((width - img_width)/ 2)
    else: 
        left = int((width - (img_width-1))/ 2)
        right = int(((width - (img_width-1))/2)-1)
    
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT,value=WHITE)
    print(image.shape)
    print(np.min(image),np.max(image))

    return image

# %%
def prep_img(img_path):
    imgRGB = img_to_array(load_img(img_path))
    imgRGB = np.array(imgRGB, dtype=float)
    print('Padded:', np.min(imgRGB), np.max(imgRGB))



    image_size_category = shape(imgRGB) 
    if image_size_category <1:
        raise Exception("Your image is too small to be used")
    elif image_size_category >4:
        raise Exception("Your image is too big to be used")

    if PCA_YN == "yes":
        RGB_compressed = pca_rgb(imgRGB, image_size_category)
        RGB_compressed = np.clip(RGB_compressed,0,1) * 255
        print("PCA ran")
    else:
        RGB_compressed = imgRGB
        print("PCA did not run")


    
    padded_image = rgb_pad(RGB_compressed)

    print('Padded:', np.min(padded_image), np.max(padded_image))
    X_LAB = color.rgb2lab(1.0/255*padded_image)[:,:,0] #1.0/255*padded_image
    print('X_LAB:', np.min(X_LAB), np.max(X_LAB))
    Y_LAB1 = color.rgb2lab(1.0/255*padded_image)[:,:,1:] #1.0/255*padded_image
    print('Y_LAB_org:', np.min(Y_LAB1), np.max(Y_LAB1))
    #Y_LAB = Y_LAB1 / 128
    Y_LAB = (Y_LAB1 + 128)/ 256
    print('Y_LAB:', np.min(Y_LAB), np.max(Y_LAB))


    print(X_LAB.shape)
    X = X_LAB.reshape(1, height, width, 1) #comment out when show predicted
    Y = Y_LAB.reshape(1, height, width, 2) #comment out when show predicted
    
    print("image processed")

    return Y, X

# %%
def prep_dataframe(df):
    for index, row in df.iterrows():
        Y, X = prep_img(row["image_path"])
        Y_train.append(Y)
        X_train.append(X)

# %%
PCA_YN = "no"

#prep_image(single_image)

df = create_dataframe(image_folder)
prep_dataframe(df)
# Out:
# processing 4 photos for training
# dropped  0 photos because they were too large to process
# dropped  0 photos because they were too small to process
# Padded: 0.0 255.0
# PCA did not run
# 256
# 256
# (256, 256, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 0.17702971378012577 100.0
# Y_LAB_org: -71.17268893328688 77.75729265802376
# Y_LAB: 0.22198168385434813 0.8037394244454052
# (256, 256)
# image processed
# Padded: 0.0 255.0
# PCA did not run
# 256
# 256
# (256, 256, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 0.039573654069084085 100.0
# Y_LAB_org: -90.63866915032773 83.20574458892847
# Y_LAB: 0.1459426986315323 0.8250224398005018
# (256, 256)
# image processed
# Padded: 0.0 255.0
# PCA did not run
# 256
# 256
# (256, 256, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 0.8013688253736433 100.0
# Y_LAB_org: -48.95291303408261 90.26595316207187
# Y_LAB: 0.3087776834606148 0.8526013795393432
# (256, 256)
# image processed
# Padded: 0.0 255.0
# PCA did not run
# 256
# 256
# (256, 256, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 0.4324681123001284 99.45842141301871
# Y_LAB_org: -37.06652323505899 65.92459281365637
# Y_LAB: 0.35520889361305086 0.7575179406783452
# (256, 256)
# image processed

# %% [markdown]
# # MODEL

# %%
BATCH_SIZE = 3
LEARNING_RATE = 0.001 #0.001
EPOCHS = 1000 #500
KERNEL_SIZE = 2 
#NUM_CLASSES = 64 #64
#IMAGE_WIDTH = 128 #128
#IMAGE_HEIGHT = 128 #128
#SIGMA = 5

# %%
def mode():
   
    model = tf.keras.Sequential([
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same', strides=(2, 2)),
    BatchNormalization(),

    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same', strides=(2, 2)),
    BatchNormalization(),

    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', strides=(2, 2)),
    BatchNormalization(),

    Conv2D(512, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(512, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(512, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    BatchNormalization(),

    Conv2D(512, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(512, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(512, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    BatchNormalization(),

    Conv2D(512, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(512, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(512, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    BatchNormalization(),

    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    BatchNormalization(),

    UpSampling2D(size=(2, 2)),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    BatchNormalization(),

    Conv2D(64, kernel_size=KERNEL_SIZE, padding='same'),
    Conv2D(64, kernel_size=KERNEL_SIZE, padding='same'),
    Conv2D(64, kernel_size=KERNEL_SIZE, padding='same'),
    BatchNormalization(),
        
    UpSampling2D(size=(2, 2)),
    Conv2D(16, kernel_size=KERNEL_SIZE, padding='same'),    
    Conv2D(16, kernel_size=KERNEL_SIZE, padding='same'),
    Conv2D(16, kernel_size=KERNEL_SIZE, padding='same'),    
    BatchNormalization(), 
        
    Conv2D(2, kernel_size=KERNEL_SIZE, padding='same'),
    Conv2D(2, kernel_size=KERNEL_SIZE, padding='same'),
    Conv2D(2, kernel_size=KERNEL_SIZE, padding='same'),
    BatchNormalization(),
        
    UpSampling2D(size=(2, 2))])
    
    model.compile(optimizer ="rmsprop", loss = "mae", metrics = ["accuracy"])
    
    return model 

#?? Acitivation function and Loss function #CategoricalCrossentropy
#Conv2D(NUM_CLASSES, kernel_size=1, padding='same', activation='softmax'), UpSampling2D(size=(4, 4))])

# %%
model = mode()

# %%
model.build((1,256,256,1))
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_372 (Conv2D)         (1, 256, 256, 64)         320
#
#  conv2d_373 (Conv2D)         (1, 128, 128, 64)         16448
#
#  batch_normalization_132 (Ba  (1, 128, 128, 64)        256
#  tchNormalization)
#
#  conv2d_374 (Conv2D)         (1, 128, 128, 128)        32896
#
#  conv2d_375 (Conv2D)         (1, 64, 64, 128)          65664
#
#  batch_normalization_133 (Ba  (1, 64, 64, 128)         512
#  tchNormalization)
#
#  conv2d_376 (Conv2D)         (1, 64, 64, 256)          131328
#
#  conv2d_377 (Conv2D)         (1, 64, 64, 256)          262400
#
#  conv2d_378 (Conv2D)         (1, 32, 32, 256)          262400
#
#  batch_normalization_134 (Ba  (1, 32, 32, 256)         1024
#  tchNormalization)
#
#  conv2d_379 (Conv2D)         (1, 32, 32, 512)          524800
#
#  conv2d_380 (Conv2D)         (1, 32, 32, 512)          1049088
#
#  conv2d_381 (Conv2D)         (1, 32, 32, 512)          1049088
#
#  batch_normalization_135 (Ba  (1, 32, 32, 512)         2048
#  tchNormalization)
#
#  conv2d_382 (Conv2D)         (1, 32, 32, 512)          1049088
#
#  conv2d_383 (Conv2D)         (1, 32, 32, 512)          1049088
#
#  conv2d_384 (Conv2D)         (1, 32, 32, 512)          1049088
#
#  batch_normalization_136 (Ba  (1, 32, 32, 512)         2048
#  tchNormalization)
#
#  conv2d_385 (Conv2D)         (1, 32, 32, 512)          1049088
#
#  conv2d_386 (Conv2D)         (1, 32, 32, 512)          1049088
#
#  conv2d_387 (Conv2D)         (1, 32, 32, 512)          1049088
#
#  batch_normalization_137 (Ba  (1, 32, 32, 512)         2048
#  tchNormalization)
#
#  conv2d_388 (Conv2D)         (1, 32, 32, 256)          524544
#
#  conv2d_389 (Conv2D)         (1, 32, 32, 256)          262400
#
#  conv2d_390 (Conv2D)         (1, 32, 32, 256)          262400
#
#  batch_normalization_138 (Ba  (1, 32, 32, 256)         1024
#  tchNormalization)
#
#  up_sampling2d_36 (UpSamplin  (1, 64, 64, 256)         0
#  g2D)
#
#  conv2d_391 (Conv2D)         (1, 64, 64, 128)          131200
#
#  conv2d_392 (Conv2D)         (1, 64, 64, 128)          65664
#
#  conv2d_393 (Conv2D)         (1, 64, 64, 128)          65664
#
#  batch_normalization_139 (Ba  (1, 64, 64, 128)         512
#  tchNormalization)
#
#  conv2d_394 (Conv2D)         (1, 64, 64, 64)           32832
#
#  conv2d_395 (Conv2D)         (1, 64, 64, 64)           16448
#
#  conv2d_396 (Conv2D)         (1, 64, 64, 64)           16448
#
#  batch_normalization_140 (Ba  (1, 64, 64, 64)          256
#  tchNormalization)
#
#  up_sampling2d_37 (UpSamplin  (1, 128, 128, 64)        0
#  g2D)
#
#  conv2d_397 (Conv2D)         (1, 128, 128, 16)         4112
#
#  conv2d_398 (Conv2D)         (1, 128, 128, 16)         1040
#
#  conv2d_399 (Conv2D)         (1, 128, 128, 16)         1040
#
#  batch_normalization_141 (Ba  (1, 128, 128, 16)        64
#  tchNormalization)
#
#  conv2d_400 (Conv2D)         (1, 128, 128, 2)          130
#
#  conv2d_401 (Conv2D)         (1, 128, 128, 2)          18
#
#  conv2d_402 (Conv2D)         (1, 128, 128, 2)          18
#
#  batch_normalization_142 (Ba  (1, 128, 128, 2)         8
#  tchNormalization)
#
#  up_sampling2d_38 (UpSamplin  (1, 256, 256, 2)         0
#  g2D)
#
# =================================================================
# Total params: 11,082,718
# Trainable params: 11,077,818
# Non-trainable params: 4,900
# _________________________________________________________________

# %%
train_data = tf.data.Dataset.from_tensor_slices((X_train, Y_train))

# %%
len(X_train)
# Out:
# 4

# %%
# %%time
history = model.fit(train_data, batch_size = BATCH_SIZE, epochs = EPOCHS, verbose = 2)  # add validation_split = 0.2
# Out:
# Epoch 1/1000
# 4/4 - 5s - loss: 0.6228 - accuracy: 0.5026 - 5s/epoch - 1s/step
# Epoch 2/1000
# 4/4 - 2s - loss: 0.5154 - accuracy: 0.5054 - 2s/epoch - 552ms/step
# Epoch 3/1000
# 4/4 - 2s - loss: 0.5084 - accuracy: 0.4987 - 2s/epoch - 590ms/step
# Epoch 4/1000
# 4/4 - 2s - loss: 0.5030 - accuracy: 0.4986 - 2s/epoch - 564ms/step
# Epoch 5/1000
# 4/4 - 2s - loss: 0.4984 - accuracy: 0.4993 - 2s/epoch - 551ms/step
# Epoch 6/1000
# 4/4 - 2s - loss: 0.4940 - accuracy: 0.4985 - 2s/epoch - 550ms/step
# Epoch 7/1000
# 4/4 - 2s - loss: 0.4898 - accuracy: 0.4987 - 2s/epoch - 537ms/step
# Epoch 8/1000
# 4/4 - 2s - loss: 0.4856 - accuracy: 0.4991 - 2s/epoch - 543ms/step
# Epoch 9/1000
# 4/4 - 2s - loss: 0.4815 - accuracy: 0.4993 - 2s/epoch - 535ms/step
# Epoch 10/1000
# 4/4 - 2s - loss: 0.4775 - accuracy: 0.4996 - 2s/epoch - 568ms/step
# Epoch 11/1000
# 4/4 - 2s - loss: 0.4734 - accuracy: 0.4975 - 2s/epoch - 598ms/step
# Epoch 12/1000
# 4/4 - 2s - loss: 0.4694 - accuracy: 0.4966 - 2s/epoch - 583ms/step
# Epoch 13/1000
# 4/4 - 2s - loss: 0.4654 - accuracy: 0.5019 - 2s/epoch - 605ms/step
# Epoch 14/1000
# 4/4 - 2s - loss: 0.4679 - accuracy: 0.5225 - 2s/epoch - 601ms/step
# Epoch 15/1000
# 4/4 - 2s - loss: 0.4788 - accuracy: 0.5127 - 2s/epoch - 570ms/step
# Epoch 16/1000
# 4/4 - 2s - loss: 0.4568 - accuracy: 0.5206 - 2s/epoch - 573ms/step
# Epoch 17/1000
# 4/4 - 2s - loss: 0.4502 - accuracy: 0.5051 - 2s/epoch - 616ms/step
# Epoch 18/1000
# 4/4 - 2s - loss: 0.4458 - accuracy: 0.4990 - 2s/epoch - 623ms/step
# Epoch 19/1000
# 4/4 - 2s - loss: 0.4417 - accuracy: 0.4944 - 2s/epoch - 585ms/step
# Epoch 20/1000
# 4/4 - 2s - loss: 0.4376 - accuracy: 0.4927 - 2s/epoch - 613ms/step
# Epoch 21/1000
# 4/4 - 2s - loss: 0.4336 - accuracy: 0.4919 - 2s/epoch - 538ms/step
# Epoch 22/1000
# 4/4 - 2s - loss: 0.4295 - accuracy: 0.4908 - 2s/epoch - 541ms/step
# Epoch 23/1000
# 4/4 - 2s - loss: 0.4255 - accuracy: 0.4893 - 2s/epoch - 587ms/step
# Epoch 24/1000
# 4/4 - 2s - loss: 0.4215 - accuracy: 0.4884 - 2s/epoch - 555ms/step
# Epoch 25/1000
# 4/4 - 2s - loss: 0.4175 - accuracy: 0.4854 - 2s/epoch - 544ms/step
# Epoch 26/1000
# 4/4 - 2s - loss: 0.4135 - accuracy: 0.4886 - 2s/epoch - 535ms/step
# Epoch 27/1000
# 4/4 - 2s - loss: 0.4095 - accuracy: 0.4879 - 2s/epoch - 578ms/step
# Epoch 28/1000
# 4/4 - 2s - loss: 0.4055 - accuracy: 0.4969 - 2s/epoch - 557ms/step
# Epoch 29/1000
# 4/4 - 2s - loss: 0.4269 - accuracy: 0.4854 - 2s/epoch - 567ms/step
# Epoch 30/1000
# 4/4 - 2s - loss: 0.4021 - accuracy: 0.4704 - 2s/epoch - 554ms/step
# Epoch 31/1000
# 4/4 - 2s - loss: 0.3949 - accuracy: 0.4881 - 2s/epoch - 551ms/step
# Epoch 32/1000
# 4/4 - 2s - loss: 0.3904 - accuracy: 0.4632 - 2s/epoch - 613ms/step
# Epoch 33/1000
# 4/4 - 2s - loss: 0.3862 - accuracy: 0.4400 - 2s/epoch - 578ms/step
# Epoch 34/1000
# 4/4 - 2s - loss: 0.3820 - accuracy: 0.4376 - 2s/epoch - 565ms/step
# Epoch 35/1000
# 4/4 - 2s - loss: 0.3780 - accuracy: 0.4354 - 2s/epoch - 566ms/step
# Epoch 36/1000
# 4/4 - 2s - loss: 0.3739 - accuracy: 0.4410 - 2s/epoch - 542ms/step
# Epoch 37/1000
# 4/4 - 2s - loss: 0.3875 - accuracy: 0.4708 - 2s/epoch - 581ms/step
# Epoch 38/1000
# 4/4 - 2s - loss: 0.3689 - accuracy: 0.4991 - 2s/epoch - 594ms/step
# Epoch 39/1000
# 4/4 - 2s - loss: 0.3630 - accuracy: 0.4820 - 2s/epoch - 620ms/step
# Epoch 40/1000
# 4/4 - 2s - loss: 0.3588 - accuracy: 0.4634 - 2s/epoch - 559ms/step
# Epoch 41/1000
# 4/4 - 2s - loss: 0.3545 - accuracy: 0.4776 - 2s/epoch - 566ms/step
# Epoch 42/1000
# 4/4 - 2s - loss: 0.3503 - accuracy: 0.4859 - 2s/epoch - 585ms/step
# Epoch 43/1000
# 4/4 - 2s - loss: 0.3462 - accuracy: 0.4873 - 2s/epoch - 568ms/step
# Epoch 44/1000
# 4/4 - 2s - loss: 0.3422 - accuracy: 0.4903 - 2s/epoch - 550ms/step
# Epoch 45/1000
# 4/4 - 2s - loss: 0.3382 - accuracy: 0.4903 - 2s/epoch - 564ms/step
# Epoch 46/1000
# 4/4 - 2s - loss: 0.3341 - accuracy: 0.4854 - 2s/epoch - 564ms/step
# Epoch 47/1000
# 4/4 - 2s - loss: 0.3301 - accuracy: 0.4882 - 2s/epoch - 552ms/step
# Epoch 48/1000
# 4/4 - 2s - loss: 0.3261 - accuracy: 0.5076 - 2s/epoch - 581ms/step
# Epoch 49/1000
# 4/4 - 2s - loss: 0.3473 - accuracy: 0.5041 - 2s/epoch - 564ms/step
# Epoch 50/1000
# 4/4 - 2s - loss: 0.3331 - accuracy: 0.5160 - 2s/epoch - 542ms/step
# Epoch 51/1000
# 4/4 - 2s - loss: 0.3178 - accuracy: 0.5432 - 2s/epoch - 548ms/step
# Epoch 52/1000
# 4/4 - 2s - loss: 0.3127 - accuracy: 0.5275 - 2s/epoch - 551ms/step
# Epoch 53/1000
# 4/4 - 2s - loss: 0.3082 - accuracy: 0.5157 - 2s/epoch - 557ms/step
# Epoch 54/1000
# 4/4 - 2s - loss: 0.3183 - accuracy: 0.5394 - 2s/epoch - 557ms/step
# Epoch 55/1000
# 4/4 - 2s - loss: 0.3038 - accuracy: 0.4534 - 2s/epoch - 555ms/step
# Epoch 56/1000
# 4/4 - 2s - loss: 0.2972 - accuracy: 0.4616 - 2s/epoch - 570ms/step
# Epoch 57/1000
# 4/4 - 3s - loss: 0.2927 - accuracy: 0.4637 - 3s/epoch - 669ms/step
# Epoch 58/1000
# 4/4 - 3s - loss: 0.2884 - accuracy: 0.4772 - 3s/epoch - 632ms/step
# Epoch 59/1000
# 4/4 - 3s - loss: 0.2844 - accuracy: 0.4894 - 3s/epoch - 641ms/step
# Epoch 60/1000
# 4/4 - 2s - loss: 0.2810 - accuracy: 0.4968 - 2s/epoch - 614ms/step
# Epoch 61/1000
# 4/4 - 2s - loss: 0.2770 - accuracy: 0.5527 - 2s/epoch - 568ms/step
# Epoch 62/1000
# 4/4 - 2s - loss: 0.2726 - accuracy: 0.5545 - 2s/epoch - 600ms/step
# Epoch 63/1000
# 4/4 - 2s - loss: 0.3839 - accuracy: 0.4959 - 2s/epoch - 554ms/step
# Epoch 64/1000
# 4/4 - 2s - loss: 0.2670 - accuracy: 0.5251 - 2s/epoch - 587ms/step
# Epoch 65/1000
# 4/4 - 2s - loss: 0.2656 - accuracy: 0.5173 - 2s/epoch - 585ms/step
# Epoch 66/1000
# 4/4 - 2s - loss: 0.2615 - accuracy: 0.5442 - 2s/epoch - 598ms/step
# Epoch 67/1000
# 4/4 - 2s - loss: 0.2712 - accuracy: 0.5386 - 2s/epoch - 575ms/step
# Epoch 68/1000
# 4/4 - 2s - loss: 0.2562 - accuracy: 0.5791 - 2s/epoch - 594ms/step
# Epoch 69/1000
# 4/4 - 2s - loss: 0.2479 - accuracy: 0.6081 - 2s/epoch - 598ms/step
# Epoch 70/1000
# 4/4 - 2s - loss: 0.2428 - accuracy: 0.6014 - 2s/epoch - 567ms/step
# Epoch 71/1000
# 4/4 - 2s - loss: 0.2385 - accuracy: 0.5966 - 2s/epoch - 580ms/step
# Epoch 72/1000
# 4/4 - 2s - loss: 0.2344 - accuracy: 0.5973 - 2s/epoch - 561ms/step
# Epoch 73/1000
# 4/4 - 2s - loss: 0.2304 - accuracy: 0.5855 - 2s/epoch - 608ms/step
# Epoch 74/1000
# 4/4 - 2s - loss: 0.2265 - accuracy: 0.6052 - 2s/epoch - 560ms/step
# Epoch 75/1000
# 4/4 - 2s - loss: 0.2225 - accuracy: 0.6018 - 2s/epoch - 565ms/step
# Epoch 76/1000
# 4/4 - 2s - loss: 0.2185 - accuracy: 0.6004 - 2s/epoch - 565ms/step
# Epoch 77/1000
# 4/4 - 2s - loss: 0.2147 - accuracy: 0.5958 - 2s/epoch - 592ms/step
# Epoch 78/1000
# 4/4 - 2s - loss: 0.2150 - accuracy: 0.5586 - 2s/epoch - 562ms/step
# Epoch 79/1000
# 4/4 - 3s - loss: 0.2086 - accuracy: 0.5740 - 3s/epoch - 632ms/step
# Epoch 80/1000
# 4/4 - 3s - loss: 0.2049 - accuracy: 0.5811 - 3s/epoch - 641ms/step
# Epoch 81/1000
# 4/4 - 2s - loss: 0.4595 - accuracy: 0.5457 - 2s/epoch - 579ms/step
# Epoch 82/1000
# 4/4 - 2s - loss: 0.3274 - accuracy: 0.5390 - 2s/epoch - 582ms/step
# Epoch 83/1000
# 4/4 - 2s - loss: 0.2413 - accuracy: 0.5480 - 2s/epoch - 571ms/step
# Epoch 84/1000
# 4/4 - 2s - loss: 0.2023 - accuracy: 0.5865 - 2s/epoch - 579ms/step
# Epoch 85/1000
# 4/4 - 2s - loss: 0.1933 - accuracy: 0.5978 - 2s/epoch - 553ms/step
# Epoch 86/1000
# 4/4 - 2s - loss: 0.1912 - accuracy: 0.5641 - 2s/epoch - 555ms/step
# Epoch 87/1000
# 4/4 - 2s - loss: 0.1857 - accuracy: 0.5943 - 2s/epoch - 555ms/step
# Epoch 88/1000
# 4/4 - 2s - loss: 0.1798 - accuracy: 0.6087 - 2s/epoch - 539ms/step
# Epoch 89/1000
# 4/4 - 2s - loss: 0.1758 - accuracy: 0.6021 - 2s/epoch - 532ms/step
# Epoch 90/1000
# 4/4 - 2s - loss: 0.1717 - accuracy: 0.6140 - 2s/epoch - 529ms/step
# Epoch 91/1000
# 4/4 - 2s - loss: 0.2283 - accuracy: 0.6027 - 2s/epoch - 558ms/step
# Epoch 92/1000
# 4/4 - 2s - loss: 0.1712 - accuracy: 0.6095 - 2s/epoch - 561ms/step
# Epoch 93/1000
# 4/4 - 2s - loss: 0.1634 - accuracy: 0.6122 - 2s/epoch - 552ms/step
# Epoch 94/1000
# 4/4 - 2s - loss: 0.1600 - accuracy: 0.6187 - 2s/epoch - 562ms/step
# Epoch 95/1000
# 4/4 - 2s - loss: 0.1549 - accuracy: 0.6178 - 2s/epoch - 562ms/step
# Epoch 96/1000
# 4/4 - 2s - loss: 0.1513 - accuracy: 0.6231 - 2s/epoch - 583ms/step
# Epoch 97/1000
# 4/4 - 2s - loss: 0.1482 - accuracy: 0.6208 - 2s/epoch - 552ms/step
# Epoch 98/1000
# 4/4 - 2s - loss: 0.1446 - accuracy: 0.6223 - 2s/epoch - 543ms/step
# Epoch 99/1000
# 4/4 - 2s - loss: 0.1401 - accuracy: 0.6204 - 2s/epoch - 531ms/step
# Epoch 100/1000
# 4/4 - 2s - loss: 0.1377 - accuracy: 0.6260 - 2s/epoch - 570ms/step
# Epoch 101/1000
# 4/4 - 2s - loss: 0.1342 - accuracy: 0.6259 - 2s/epoch - 592ms/step
# Epoch 102/1000
# 4/4 - 2s - loss: 0.1427 - accuracy: 0.6135 - 2s/epoch - 572ms/step
# Epoch 103/1000
# 4/4 - 2s - loss: 0.1340 - accuracy: 0.6122 - 2s/epoch - 566ms/step
# Epoch 104/1000
# 4/4 - 2s - loss: 0.1404 - accuracy: 0.6117 - 2s/epoch - 549ms/step
# Epoch 105/1000
# 4/4 - 2s - loss: 0.1586 - accuracy: 0.5508 - 2s/epoch - 552ms/step
# Epoch 106/1000
# 4/4 - 2s - loss: 0.1340 - accuracy: 0.6027 - 2s/epoch - 548ms/step
# Epoch 107/1000
# 4/4 - 2s - loss: 0.1335 - accuracy: 0.6082 - 2s/epoch - 539ms/step
# Epoch 108/1000
# 4/4 - 2s - loss: 0.1314 - accuracy: 0.6100 - 2s/epoch - 574ms/step
# Epoch 109/1000
# 4/4 - 2s - loss: 0.1239 - accuracy: 0.6133 - 2s/epoch - 540ms/step
# Epoch 110/1000
# 4/4 - 2s - loss: 0.1996 - accuracy: 0.5786 - 2s/epoch - 553ms/step
# Epoch 111/1000
# 4/4 - 2s - loss: 0.1479 - accuracy: 0.6082 - 2s/epoch - 570ms/step
# Epoch 112/1000
# 4/4 - 2s - loss: 0.1271 - accuracy: 0.6096 - 2s/epoch - 560ms/step
# Epoch 113/1000
# 4/4 - 2s - loss: 0.1336 - accuracy: 0.5879 - 2s/epoch - 585ms/step
# Epoch 114/1000
# 4/4 - 2s - loss: 0.1304 - accuracy: 0.5944 - 2s/epoch - 585ms/step
# Epoch 115/1000
# 4/4 - 2s - loss: 0.1165 - accuracy: 0.6113 - 2s/epoch - 584ms/step
# Epoch 116/1000
# 4/4 - 2s - loss: 0.1076 - accuracy: 0.6127 - 2s/epoch - 552ms/step
# Epoch 117/1000
# 4/4 - 2s - loss: 0.1009 - accuracy: 0.6193 - 2s/epoch - 543ms/step
# Epoch 118/1000
# 4/4 - 2s - loss: 0.0984 - accuracy: 0.6184 - 2s/epoch - 538ms/step
# Epoch 119/1000
# 4/4 - 2s - loss: 0.0969 - accuracy: 0.6183 - 2s/epoch - 571ms/step
# Epoch 120/1000
# 4/4 - 2s - loss: 0.0955 - accuracy: 0.6180 - 2s/epoch - 554ms/step
# Epoch 121/1000
# 4/4 - 2s - loss: 0.0940 - accuracy: 0.6185 - 2s/epoch - 580ms/step
# Epoch 122/1000
# 4/4 - 2s - loss: 0.0928 - accuracy: 0.6181 - 2s/epoch - 580ms/step
# Epoch 123/1000
# 4/4 - 2s - loss: 0.0917 - accuracy: 0.6181 - 2s/epoch - 559ms/step
# Epoch 124/1000
# 4/4 - 2s - loss: 0.0912 - accuracy: 0.6182 - 2s/epoch - 547ms/step
# Epoch 125/1000
# 4/4 - 2s - loss: 0.0938 - accuracy: 0.6175 - 2s/epoch - 533ms/step
# Epoch 126/1000
# 4/4 - 2s - loss: 0.0913 - accuracy: 0.6180 - 2s/epoch - 540ms/step
# Epoch 127/1000
# 4/4 - 2s - loss: 0.0893 - accuracy: 0.6181 - 2s/epoch - 561ms/step
# Epoch 128/1000
# 4/4 - 2s - loss: 0.0875 - accuracy: 0.6183 - 2s/epoch - 542ms/step
# Epoch 129/1000
# 4/4 - 2s - loss: 0.0871 - accuracy: 0.6184 - 2s/epoch - 544ms/step
# Epoch 130/1000
# 4/4 - 2s - loss: 0.0869 - accuracy: 0.6183 - 2s/epoch - 554ms/step
# Epoch 131/1000
# 4/4 - 2s - loss: 0.0860 - accuracy: 0.6183 - 2s/epoch - 541ms/step
# Epoch 132/1000
# 4/4 - 2s - loss: 0.0874 - accuracy: 0.6186 - 2s/epoch - 587ms/step
# Epoch 133/1000
# 4/4 - 2s - loss: 0.0856 - accuracy: 0.6184 - 2s/epoch - 548ms/step
# Epoch 134/1000
# 4/4 - 2s - loss: 0.0842 - accuracy: 0.6183 - 2s/epoch - 567ms/step
# Epoch 135/1000
# 4/4 - 2s - loss: 0.0839 - accuracy: 0.6183 - 2s/epoch - 566ms/step
# Epoch 136/1000
# 4/4 - 2s - loss: 0.0835 - accuracy: 0.6183 - 2s/epoch - 556ms/step
# Epoch 137/1000
# 4/4 - 2s - loss: 0.0839 - accuracy: 0.6175 - 2s/epoch - 567ms/step
# Epoch 138/1000
# 4/4 - 2s - loss: 0.0837 - accuracy: 0.6165 - 2s/epoch - 584ms/step
# Epoch 139/1000
# 4/4 - 2s - loss: 0.0828 - accuracy: 0.6156 - 2s/epoch - 551ms/step
# Epoch 140/1000
# 4/4 - 2s - loss: 0.1568 - accuracy: 0.6177 - 2s/epoch - 560ms/step
# Epoch 141/1000
# 4/4 - 2s - loss: 0.0849 - accuracy: 0.6182 - 2s/epoch - 539ms/step
# Epoch 142/1000
# 4/4 - 2s - loss: 0.0832 - accuracy: 0.6183 - 2s/epoch - 572ms/step
# Epoch 143/1000
# 4/4 - 2s - loss: 0.0831 - accuracy: 0.6165 - 2s/epoch - 541ms/step
# Epoch 144/1000
# 4/4 - 2s - loss: 0.0832 - accuracy: 0.6164 - 2s/epoch - 564ms/step
# Epoch 145/1000
# 4/4 - 2s - loss: 0.0825 - accuracy: 0.6147 - 2s/epoch - 550ms/step
# Epoch 146/1000
# 4/4 - 2s - loss: 0.0831 - accuracy: 0.6132 - 2s/epoch - 540ms/step
# Epoch 147/1000
# 4/4 - 2s - loss: 0.0874 - accuracy: 0.6134 - 2s/epoch - 535ms/step
# Epoch 148/1000
# 4/4 - 2s - loss: 0.0838 - accuracy: 0.6159 - 2s/epoch - 532ms/step
# Epoch 149/1000
# 4/4 - 2s - loss: 0.0873 - accuracy: 0.6160 - 2s/epoch - 549ms/step
# Epoch 150/1000
# 4/4 - 2s - loss: 0.0831 - accuracy: 0.6148 - 2s/epoch - 596ms/step
# Epoch 151/1000
# 4/4 - 2s - loss: 0.0824 - accuracy: 0.6135 - 2s/epoch - 575ms/step
# Epoch 152/1000
# 4/4 - 2s - loss: 0.0820 - accuracy: 0.6137 - 2s/epoch - 565ms/step
# Epoch 153/1000
# 4/4 - 2s - loss: 0.0818 - accuracy: 0.6151 - 2s/epoch - 540ms/step
# Epoch 154/1000
# 4/4 - 2s - loss: 0.0811 - accuracy: 0.6151 - 2s/epoch - 564ms/step
# Epoch 155/1000
# 4/4 - 2s - loss: 0.0806 - accuracy: 0.6153 - 2s/epoch - 556ms/step
# Epoch 156/1000
# 4/4 - 2s - loss: 0.0806 - accuracy: 0.6148 - 2s/epoch - 584ms/step
# Epoch 157/1000
# 4/4 - 2s - loss: 0.0795 - accuracy: 0.6136 - 2s/epoch - 561ms/step
# Epoch 158/1000
# 4/4 - 2s - loss: 0.0793 - accuracy: 0.6150 - 2s/epoch - 593ms/step
# Epoch 159/1000
# 4/4 - 2s - loss: 0.0795 - accuracy: 0.6147 - 2s/epoch - 543ms/step
# Epoch 160/1000
# 4/4 - 2s - loss: 0.0787 - accuracy: 0.6161 - 2s/epoch - 534ms/step
# Epoch 161/1000
# 4/4 - 2s - loss: 0.0782 - accuracy: 0.6159 - 2s/epoch - 587ms/step
# Epoch 162/1000
# 4/4 - 3s - loss: 0.0780 - accuracy: 0.6158 - 3s/epoch - 628ms/step
# Epoch 163/1000
# 4/4 - 3s - loss: 0.0779 - accuracy: 0.6149 - 3s/epoch - 639ms/step
# Epoch 164/1000
# 4/4 - 2s - loss: 0.0785 - accuracy: 0.6149 - 2s/epoch - 614ms/step
# Epoch 165/1000
# 4/4 - 2s - loss: 0.0774 - accuracy: 0.6166 - 2s/epoch - 613ms/step
# Epoch 166/1000
# 4/4 - 2s - loss: 0.0767 - accuracy: 0.6157 - 2s/epoch - 551ms/step
# Epoch 167/1000
# 4/4 - 2s - loss: 0.0768 - accuracy: 0.6151 - 2s/epoch - 566ms/step
# Epoch 168/1000
# 4/4 - 2s - loss: 0.0769 - accuracy: 0.6155 - 2s/epoch - 585ms/step
# Epoch 169/1000
# 4/4 - 2s - loss: 0.0757 - accuracy: 0.6153 - 2s/epoch - 577ms/step
# Epoch 170/1000
# 4/4 - 2s - loss: 0.0758 - accuracy: 0.6156 - 2s/epoch - 562ms/step
# Epoch 171/1000
# 4/4 - 3s - loss: 0.0755 - accuracy: 0.6153 - 3s/epoch - 639ms/step
# Epoch 172/1000
# 4/4 - 2s - loss: 0.0747 - accuracy: 0.6153 - 2s/epoch - 580ms/step
# Epoch 173/1000
# 4/4 - 2s - loss: 0.0754 - accuracy: 0.6155 - 2s/epoch - 549ms/step
# Epoch 174/1000
# 4/4 - 2s - loss: 0.0739 - accuracy: 0.6153 - 2s/epoch - 566ms/step
# Epoch 175/1000
# 4/4 - 2s - loss: 0.0736 - accuracy: 0.6169 - 2s/epoch - 553ms/step
# Epoch 176/1000
# 4/4 - 2s - loss: 0.0734 - accuracy: 0.6168 - 2s/epoch - 541ms/step
# Epoch 177/1000
# 4/4 - 2s - loss: 0.0724 - accuracy: 0.6139 - 2s/epoch - 541ms/step
# Epoch 178/1000
# 4/4 - 2s - loss: 0.0725 - accuracy: 0.6122 - 2s/epoch - 556ms/step
# Epoch 179/1000
# 4/4 - 2s - loss: 0.0733 - accuracy: 0.6122 - 2s/epoch - 550ms/step
# Epoch 180/1000
# 4/4 - 2s - loss: 0.0717 - accuracy: 0.6115 - 2s/epoch - 538ms/step
# Epoch 181/1000
# 4/4 - 2s - loss: 0.0714 - accuracy: 0.6173 - 2s/epoch - 564ms/step
# Epoch 182/1000
# 4/4 - 2s - loss: 0.0714 - accuracy: 0.6122 - 2s/epoch - 551ms/step
# Epoch 183/1000
# 4/4 - 2s - loss: 0.0704 - accuracy: 0.6096 - 2s/epoch - 562ms/step
# Epoch 184/1000
# 4/4 - 2s - loss: 0.0699 - accuracy: 0.6190 - 2s/epoch - 605ms/step
# Epoch 185/1000
# 4/4 - 2s - loss: 0.0711 - accuracy: 0.6205 - 2s/epoch - 592ms/step
# Epoch 186/1000
# 4/4 - 3s - loss: 0.0693 - accuracy: 0.6192 - 3s/epoch - 674ms/step
# Epoch 187/1000
# 4/4 - 3s - loss: 0.0708 - accuracy: 0.6138 - 3s/epoch - 627ms/step
# Epoch 188/1000
# 4/4 - 2s - loss: 0.0690 - accuracy: 0.6080 - 2s/epoch - 581ms/step
# Epoch 189/1000
# 4/4 - 2s - loss: 0.0825 - accuracy: 0.6142 - 2s/epoch - 577ms/step
# Epoch 190/1000
# 4/4 - 2s - loss: 0.0702 - accuracy: 0.6121 - 2s/epoch - 547ms/step
# Epoch 191/1000
# 4/4 - 2s - loss: 0.0687 - accuracy: 0.6035 - 2s/epoch - 547ms/step
# Epoch 192/1000
# 4/4 - 2s - loss: 0.0709 - accuracy: 0.6099 - 2s/epoch - 555ms/step
# Epoch 193/1000
# 4/4 - 2s - loss: 0.0756 - accuracy: 0.6236 - 2s/epoch - 565ms/step
# Epoch 194/1000
# 4/4 - 2s - loss: 0.0685 - accuracy: 0.6002 - 2s/epoch - 540ms/step
# Epoch 195/1000
# 4/4 - 2s - loss: 0.0681 - accuracy: 0.6050 - 2s/epoch - 534ms/step
# Epoch 196/1000
# 4/4 - 2s - loss: 0.0682 - accuracy: 0.6014 - 2s/epoch - 543ms/step
# Epoch 197/1000
# 4/4 - 2s - loss: 0.0679 - accuracy: 0.6101 - 2s/epoch - 533ms/step
# Epoch 198/1000
# 4/4 - 2s - loss: 0.0671 - accuracy: 0.6045 - 2s/epoch - 540ms/step
# Epoch 199/1000
# 4/4 - 2s - loss: 0.0671 - accuracy: 0.6010 - 2s/epoch - 548ms/step
# Epoch 200/1000
# 4/4 - 2s - loss: 0.0673 - accuracy: 0.6120 - 2s/epoch - 597ms/step
# Epoch 201/1000
# 4/4 - 2s - loss: 0.0671 - accuracy: 0.5996 - 2s/epoch - 542ms/step
# Epoch 202/1000
# 4/4 - 2s - loss: 0.0663 - accuracy: 0.6000 - 2s/epoch - 536ms/step
# Epoch 203/1000
# 4/4 - 2s - loss: 0.0668 - accuracy: 0.6148 - 2s/epoch - 558ms/step
# Epoch 204/1000
# 4/4 - 2s - loss: 0.0660 - accuracy: 0.6122 - 2s/epoch - 537ms/step
# Epoch 205/1000
# 4/4 - 2s - loss: 0.0669 - accuracy: 0.6205 - 2s/epoch - 532ms/step
# Epoch 206/1000
# 4/4 - 2s - loss: 0.0666 - accuracy: 0.6056 - 2s/epoch - 545ms/step
# Epoch 207/1000
# 4/4 - 2s - loss: 0.0660 - accuracy: 0.5983 - 2s/epoch - 558ms/step
# Epoch 208/1000
# 4/4 - 2s - loss: 0.0669 - accuracy: 0.5954 - 2s/epoch - 534ms/step
# Epoch 209/1000
# 4/4 - 2s - loss: 0.0656 - accuracy: 0.5928 - 2s/epoch - 530ms/step
# Epoch 210/1000
# 4/4 - 2s - loss: 0.0655 - accuracy: 0.5996 - 2s/epoch - 543ms/step
# Epoch 211/1000
# 4/4 - 2s - loss: 0.0642 - accuracy: 0.6079 - 2s/epoch - 553ms/step
# Epoch 212/1000
# 4/4 - 2s - loss: 0.0644 - accuracy: 0.5880 - 2s/epoch - 530ms/step
# Epoch 213/1000
# 4/4 - 2s - loss: 0.0662 - accuracy: 0.6015 - 2s/epoch - 530ms/step
# Epoch 214/1000
# 4/4 - 2s - loss: 0.0653 - accuracy: 0.6158 - 2s/epoch - 539ms/step
# Epoch 215/1000
# 4/4 - 2s - loss: 0.0637 - accuracy: 0.5984 - 2s/epoch - 544ms/step
# Epoch 216/1000
# 4/4 - 2s - loss: 0.0633 - accuracy: 0.5948 - 2s/epoch - 528ms/step
# Epoch 217/1000
# 4/4 - 2s - loss: 0.0636 - accuracy: 0.6068 - 2s/epoch - 571ms/step
# Epoch 218/1000
# 4/4 - 2s - loss: 0.0648 - accuracy: 0.6053 - 2s/epoch - 548ms/step
# Epoch 219/1000
# 4/4 - 2s - loss: 0.0633 - accuracy: 0.5975 - 2s/epoch - 538ms/step
# Epoch 220/1000
# 4/4 - 2s - loss: 0.0621 - accuracy: 0.5919 - 2s/epoch - 552ms/step
# Epoch 221/1000
# 4/4 - 2s - loss: 0.0620 - accuracy: 0.5968 - 2s/epoch - 575ms/step
# Epoch 222/1000
# 4/4 - 2s - loss: 0.0618 - accuracy: 0.5918 - 2s/epoch - 568ms/step
# Epoch 223/1000
# 4/4 - 2s - loss: 0.0627 - accuracy: 0.5979 - 2s/epoch - 546ms/step
# Epoch 224/1000
# 4/4 - 2s - loss: 0.0637 - accuracy: 0.6142 - 2s/epoch - 541ms/step
# Epoch 225/1000
# 4/4 - 2s - loss: 0.0617 - accuracy: 0.5993 - 2s/epoch - 552ms/step
# Epoch 226/1000
# 4/4 - 2s - loss: 0.0622 - accuracy: 0.6069 - 2s/epoch - 573ms/step
# Epoch 227/1000
# 4/4 - 2s - loss: 0.0613 - accuracy: 0.5988 - 2s/epoch - 556ms/step
# Epoch 228/1000
# 4/4 - 2s - loss: 0.0602 - accuracy: 0.5920 - 2s/epoch - 551ms/step
# Epoch 229/1000
# 4/4 - 2s - loss: 0.0607 - accuracy: 0.5983 - 2s/epoch - 573ms/step
# Epoch 230/1000
# 4/4 - 2s - loss: 0.0610 - accuracy: 0.5925 - 2s/epoch - 550ms/step
# Epoch 231/1000
# 4/4 - 2s - loss: 0.0604 - accuracy: 0.6096 - 2s/epoch - 580ms/step
# Epoch 232/1000
# 4/4 - 2s - loss: 0.0600 - accuracy: 0.6085 - 2s/epoch - 586ms/step
# Epoch 233/1000
# 4/4 - 2s - loss: 0.0591 - accuracy: 0.6124 - 2s/epoch - 552ms/step
# Epoch 234/1000
# 4/4 - 2s - loss: 0.0600 - accuracy: 0.6049 - 2s/epoch - 545ms/step
# Epoch 235/1000
# 4/4 - 2s - loss: 0.0594 - accuracy: 0.6069 - 2s/epoch - 584ms/step
# Epoch 236/1000
# 4/4 - 2s - loss: 0.0586 - accuracy: 0.6055 - 2s/epoch - 573ms/step
# Epoch 237/1000
# 4/4 - 2s - loss: 0.0577 - accuracy: 0.6256 - 2s/epoch - 585ms/step
# Epoch 238/1000
# 4/4 - 2s - loss: 0.0598 - accuracy: 0.6094 - 2s/epoch - 572ms/step
# Epoch 239/1000
# 4/4 - 2s - loss: 0.0584 - accuracy: 0.6190 - 2s/epoch - 588ms/step
# Epoch 240/1000
# 4/4 - 3s - loss: 0.0586 - accuracy: 0.6072 - 3s/epoch - 632ms/step
# Epoch 241/1000
# 4/4 - 3s - loss: 0.0575 - accuracy: 0.6268 - 3s/epoch - 627ms/step
# Epoch 242/1000
# 4/4 - 2s - loss: 0.0574 - accuracy: 0.6232 - 2s/epoch - 584ms/step
# Epoch 243/1000
# 4/4 - 2s - loss: 0.0579 - accuracy: 0.6343 - 2s/epoch - 570ms/step
# Epoch 244/1000
# 4/4 - 2s - loss: 0.0586 - accuracy: 0.6089 - 2s/epoch - 549ms/step
# Epoch 245/1000
# 4/4 - 2s - loss: 0.0566 - accuracy: 0.6368 - 2s/epoch - 539ms/step
# Epoch 246/1000
# 4/4 - 2s - loss: 0.0566 - accuracy: 0.6331 - 2s/epoch - 537ms/step
# Epoch 247/1000
# 4/4 - 2s - loss: 0.0565 - accuracy: 0.6246 - 2s/epoch - 537ms/step
# Epoch 248/1000
# 4/4 - 2s - loss: 0.0555 - accuracy: 0.6395 - 2s/epoch - 556ms/step
# Epoch 249/1000
# 4/4 - 2s - loss: 0.0556 - accuracy: 0.6426 - 2s/epoch - 576ms/step
# Epoch 250/1000
# 4/4 - 2s - loss: 0.0551 - accuracy: 0.6537 - 2s/epoch - 571ms/step
# Epoch 251/1000
# 4/4 - 2s - loss: 0.0554 - accuracy: 0.6351 - 2s/epoch - 623ms/step
# Epoch 252/1000
# 4/4 - 2s - loss: 0.0551 - accuracy: 0.6403 - 2s/epoch - 543ms/step
# Epoch 253/1000
# 4/4 - 2s - loss: 0.0545 - accuracy: 0.6394 - 2s/epoch - 574ms/step
# Epoch 254/1000
# 4/4 - 2s - loss: 0.0546 - accuracy: 0.6475 - 2s/epoch - 564ms/step
# Epoch 255/1000
# 4/4 - 2s - loss: 0.0544 - accuracy: 0.6525 - 2s/epoch - 534ms/step
# Epoch 256/1000
# 4/4 - 2s - loss: 0.0540 - accuracy: 0.6453 - 2s/epoch - 556ms/step
# Epoch 257/1000
# 4/4 - 2s - loss: 0.0533 - accuracy: 0.6420 - 2s/epoch - 585ms/step
# Epoch 258/1000
# 4/4 - 2s - loss: 0.0524 - accuracy: 0.6640 - 2s/epoch - 560ms/step
# Epoch 259/1000
# 4/4 - 2s - loss: 0.0538 - accuracy: 0.6457 - 2s/epoch - 543ms/step
# Epoch 260/1000
# 4/4 - 2s - loss: 0.0515 - accuracy: 0.6639 - 2s/epoch - 589ms/step
# Epoch 261/1000
# 4/4 - 2s - loss: 0.0532 - accuracy: 0.6613 - 2s/epoch - 600ms/step
# Epoch 262/1000
# 4/4 - 2s - loss: 0.0526 - accuracy: 0.6768 - 2s/epoch - 573ms/step
# Epoch 263/1000
# 4/4 - 2s - loss: 0.0509 - accuracy: 0.6727 - 2s/epoch - 575ms/step
# Epoch 264/1000
# 4/4 - 2s - loss: 0.0503 - accuracy: 0.6668 - 2s/epoch - 622ms/step
# Epoch 265/1000
# 4/4 - 2s - loss: 0.0511 - accuracy: 0.6696 - 2s/epoch - 597ms/step
# Epoch 266/1000
# 4/4 - 2s - loss: 0.0520 - accuracy: 0.6485 - 2s/epoch - 565ms/step
# Epoch 267/1000
# 4/4 - 2s - loss: 0.0509 - accuracy: 0.6635 - 2s/epoch - 562ms/step
# Epoch 268/1000
# 4/4 - 2s - loss: 0.0507 - accuracy: 0.6753 - 2s/epoch - 549ms/step
# Epoch 269/1000
# 4/4 - 2s - loss: 0.0501 - accuracy: 0.6884 - 2s/epoch - 548ms/step
# Epoch 270/1000
# 4/4 - 2s - loss: 0.0491 - accuracy: 0.6857 - 2s/epoch - 545ms/step
# Epoch 271/1000
# 4/4 - 2s - loss: 0.0499 - accuracy: 0.6927 - 2s/epoch - 583ms/step
# Epoch 272/1000
# 4/4 - 2s - loss: 0.0495 - accuracy: 0.6826 - 2s/epoch - 559ms/step
# Epoch 273/1000
# 4/4 - 2s - loss: 0.0499 - accuracy: 0.6670 - 2s/epoch - 539ms/step
# Epoch 274/1000
# 4/4 - 2s - loss: 0.0483 - accuracy: 0.6724 - 2s/epoch - 605ms/step
# Epoch 275/1000
# 4/4 - 2s - loss: 0.0480 - accuracy: 0.6771 - 2s/epoch - 610ms/step
# Epoch 276/1000
# 4/4 - 2s - loss: 0.0478 - accuracy: 0.6878 - 2s/epoch - 611ms/step
# Epoch 277/1000
# 4/4 - 2s - loss: 0.0492 - accuracy: 0.6921 - 2s/epoch - 597ms/step
# Epoch 278/1000
# 4/4 - 2s - loss: 0.0483 - accuracy: 0.7138 - 2s/epoch - 600ms/step
# Epoch 279/1000
# 4/4 - 2s - loss: 0.0474 - accuracy: 0.6948 - 2s/epoch - 559ms/step
# Epoch 280/1000
# 4/4 - 2s - loss: 0.0480 - accuracy: 0.6954 - 2s/epoch - 531ms/step
# Epoch 281/1000
# 4/4 - 2s - loss: 0.0475 - accuracy: 0.6895 - 2s/epoch - 531ms/step
# Epoch 282/1000
# 4/4 - 2s - loss: 0.0475 - accuracy: 0.6820 - 2s/epoch - 550ms/step
# Epoch 283/1000
# 4/4 - 2s - loss: 0.0475 - accuracy: 0.6990 - 2s/epoch - 586ms/step
# Epoch 284/1000
# 4/4 - 2s - loss: 0.0465 - accuracy: 0.6870 - 2s/epoch - 541ms/step
# Epoch 285/1000
# 4/4 - 2s - loss: 0.0455 - accuracy: 0.7212 - 2s/epoch - 568ms/step
# Epoch 286/1000
# 4/4 - 2s - loss: 0.0474 - accuracy: 0.6823 - 2s/epoch - 573ms/step
# Epoch 287/1000
# 4/4 - 2s - loss: 0.0457 - accuracy: 0.6993 - 2s/epoch - 534ms/step
# Epoch 288/1000
# 4/4 - 2s - loss: 0.0453 - accuracy: 0.7116 - 2s/epoch - 554ms/step
# Epoch 289/1000
# 4/4 - 2s - loss: 0.0448 - accuracy: 0.7372 - 2s/epoch - 565ms/step
# Epoch 290/1000
# 4/4 - 2s - loss: 0.0467 - accuracy: 0.6542 - 2s/epoch - 595ms/step
# Epoch 291/1000
# 4/4 - 2s - loss: 0.0448 - accuracy: 0.6955 - 2s/epoch - 593ms/step
# Epoch 292/1000
# 4/4 - 2s - loss: 0.0445 - accuracy: 0.7048 - 2s/epoch - 605ms/step
# Epoch 293/1000
# 4/4 - 2s - loss: 0.0447 - accuracy: 0.7187 - 2s/epoch - 590ms/step
# Epoch 294/1000
# 4/4 - 2s - loss: 0.0456 - accuracy: 0.7165 - 2s/epoch - 572ms/step
# Epoch 295/1000
# 4/4 - 2s - loss: 0.0435 - accuracy: 0.7151 - 2s/epoch - 565ms/step
# Epoch 296/1000
# 4/4 - 2s - loss: 0.0430 - accuracy: 0.6974 - 2s/epoch - 559ms/step
# Epoch 297/1000
# 4/4 - 2s - loss: 0.0443 - accuracy: 0.7289 - 2s/epoch - 572ms/step
# Epoch 298/1000
# 4/4 - 2s - loss: 0.0430 - accuracy: 0.7156 - 2s/epoch - 608ms/step
# Epoch 299/1000
# 4/4 - 2s - loss: 0.0446 - accuracy: 0.6933 - 2s/epoch - 586ms/step
# Epoch 300/1000
# 4/4 - 2s - loss: 0.0431 - accuracy: 0.7282 - 2s/epoch - 541ms/step
# Epoch 301/1000
# 4/4 - 2s - loss: 0.0430 - accuracy: 0.6985 - 2s/epoch - 550ms/step
# Epoch 302/1000
# 4/4 - 2s - loss: 0.0419 - accuracy: 0.7363 - 2s/epoch - 565ms/step
# Epoch 303/1000
# 4/4 - 2s - loss: 0.0424 - accuracy: 0.7271 - 2s/epoch - 613ms/step
# Epoch 304/1000
# 4/4 - 3s - loss: 0.0433 - accuracy: 0.7302 - 3s/epoch - 674ms/step
# Epoch 305/1000
# 4/4 - 3s - loss: 0.0441 - accuracy: 0.6800 - 3s/epoch - 691ms/step
# Epoch 306/1000
# 4/4 - 3s - loss: 0.0421 - accuracy: 0.7430 - 3s/epoch - 649ms/step
# Epoch 307/1000
# 4/4 - 2s - loss: 0.0416 - accuracy: 0.7411 - 2s/epoch - 613ms/step
# Epoch 308/1000
# 4/4 - 2s - loss: 0.0414 - accuracy: 0.7187 - 2s/epoch - 571ms/step
# Epoch 309/1000
# 4/4 - 2s - loss: 0.0405 - accuracy: 0.7503 - 2s/epoch - 583ms/step
# Epoch 310/1000
# 4/4 - 2s - loss: 0.0401 - accuracy: 0.7426 - 2s/epoch - 602ms/step
# Epoch 311/1000
# 4/4 - 2s - loss: 0.0414 - accuracy: 0.7517 - 2s/epoch - 574ms/step
# Epoch 312/1000
# 4/4 - 2s - loss: 0.0424 - accuracy: 0.7283 - 2s/epoch - 569ms/step
# Epoch 313/1000
# 4/4 - 2s - loss: 0.0408 - accuracy: 0.7149 - 2s/epoch - 571ms/step
# Epoch 314/1000
# 4/4 - 2s - loss: 0.0404 - accuracy: 0.7351 - 2s/epoch - 552ms/step
# Epoch 315/1000
# 4/4 - 2s - loss: 0.0392 - accuracy: 0.7619 - 2s/epoch - 552ms/step
# Epoch 316/1000
# 4/4 - 2s - loss: 0.0402 - accuracy: 0.7500 - 2s/epoch - 588ms/step
# Epoch 317/1000
# 4/4 - 2s - loss: 0.0398 - accuracy: 0.7339 - 2s/epoch - 585ms/step
# Epoch 318/1000
# 4/4 - 2s - loss: 0.0407 - accuracy: 0.7662 - 2s/epoch - 580ms/step
# Epoch 319/1000
# 4/4 - 2s - loss: 0.0393 - accuracy: 0.7437 - 2s/epoch - 562ms/step
# Epoch 320/1000
# 4/4 - 2s - loss: 0.0390 - accuracy: 0.7449 - 2s/epoch - 550ms/step
# Epoch 321/1000
# 4/4 - 2s - loss: 0.0388 - accuracy: 0.7694 - 2s/epoch - 553ms/step
# Epoch 322/1000
# 4/4 - 2s - loss: 0.0391 - accuracy: 0.7397 - 2s/epoch - 564ms/step
# Epoch 323/1000
# 4/4 - 2s - loss: 0.0385 - accuracy: 0.7626 - 2s/epoch - 573ms/step
# Epoch 324/1000
# 4/4 - 2s - loss: 0.0394 - accuracy: 0.7513 - 2s/epoch - 567ms/step
# Epoch 325/1000
# 4/4 - 2s - loss: 0.0385 - accuracy: 0.7270 - 2s/epoch - 582ms/step
# Epoch 326/1000
# 4/4 - 2s - loss: 0.0380 - accuracy: 0.7634 - 2s/epoch - 605ms/step
# Epoch 327/1000
# 4/4 - 2s - loss: 0.0381 - accuracy: 0.7605 - 2s/epoch - 610ms/step
# Epoch 328/1000
# 4/4 - 2s - loss: 0.0377 - accuracy: 0.7679 - 2s/epoch - 579ms/step
# Epoch 329/1000
# 4/4 - 2s - loss: 0.0401 - accuracy: 0.7647 - 2s/epoch - 573ms/step
# Epoch 330/1000
# 4/4 - 2s - loss: 0.0374 - accuracy: 0.7664 - 2s/epoch - 570ms/step
# Epoch 331/1000
# 4/4 - 2s - loss: 0.0390 - accuracy: 0.7281 - 2s/epoch - 562ms/step
# Epoch 332/1000
# 4/4 - 2s - loss: 0.0378 - accuracy: 0.7651 - 2s/epoch - 546ms/step
# Epoch 333/1000
# 4/4 - 2s - loss: 0.0374 - accuracy: 0.7523 - 2s/epoch - 551ms/step
# Epoch 334/1000
# 4/4 - 2s - loss: 0.0371 - accuracy: 0.7437 - 2s/epoch - 543ms/step
# Epoch 335/1000
# 4/4 - 2s - loss: 0.0373 - accuracy: 0.7813 - 2s/epoch - 536ms/step
# Epoch 336/1000
# 4/4 - 2s - loss: 0.0368 - accuracy: 0.7616 - 2s/epoch - 543ms/step
# Epoch 337/1000
# 4/4 - 2s - loss: 0.0369 - accuracy: 0.7565 - 2s/epoch - 558ms/step
# Epoch 338/1000
# 4/4 - 2s - loss: 0.0373 - accuracy: 0.7702 - 2s/epoch - 539ms/step
# Epoch 339/1000
# 4/4 - 2s - loss: 0.0429 - accuracy: 0.7619 - 2s/epoch - 557ms/step
# Epoch 340/1000
# 4/4 - 2s - loss: 0.0366 - accuracy: 0.7564 - 2s/epoch - 592ms/step
# Epoch 341/1000
# 4/4 - 2s - loss: 0.0356 - accuracy: 0.7871 - 2s/epoch - 593ms/step
# Epoch 342/1000
# 4/4 - 2s - loss: 0.0363 - accuracy: 0.7687 - 2s/epoch - 584ms/step
# Epoch 343/1000
# 4/4 - 2s - loss: 0.0355 - accuracy: 0.7534 - 2s/epoch - 579ms/step
# Epoch 344/1000
# 4/4 - 2s - loss: 0.0357 - accuracy: 0.7827 - 2s/epoch - 580ms/step
# Epoch 345/1000
# 4/4 - 2s - loss: 0.0358 - accuracy: 0.7770 - 2s/epoch - 592ms/step
# Epoch 346/1000
# 4/4 - 2s - loss: 0.0360 - accuracy: 0.7865 - 2s/epoch - 598ms/step
# Epoch 347/1000
# 4/4 - 3s - loss: 0.0343 - accuracy: 0.7847 - 3s/epoch - 627ms/step
# Epoch 348/1000
# 4/4 - 2s - loss: 0.0363 - accuracy: 0.7344 - 2s/epoch - 574ms/step
# Epoch 349/1000
# 4/4 - 2s - loss: 0.0351 - accuracy: 0.7718 - 2s/epoch - 587ms/step
# Epoch 350/1000
# 4/4 - 2s - loss: 0.0353 - accuracy: 0.7599 - 2s/epoch - 573ms/step
# Epoch 351/1000
# 4/4 - 2s - loss: 0.0425 - accuracy: 0.7600 - 2s/epoch - 560ms/step
# Epoch 352/1000
# 4/4 - 2s - loss: 0.0383 - accuracy: 0.7415 - 2s/epoch - 569ms/step
# Epoch 353/1000
# 4/4 - 2s - loss: 0.0355 - accuracy: 0.7669 - 2s/epoch - 603ms/step
# Epoch 354/1000
# 4/4 - 2s - loss: 0.0340 - accuracy: 0.7740 - 2s/epoch - 573ms/step
# Epoch 355/1000
# 4/4 - 2s - loss: 0.0345 - accuracy: 0.7732 - 2s/epoch - 560ms/step
# Epoch 356/1000
# 4/4 - 2s - loss: 0.0348 - accuracy: 0.7380 - 2s/epoch - 553ms/step
# Epoch 357/1000
# 4/4 - 2s - loss: 0.0342 - accuracy: 0.7704 - 2s/epoch - 566ms/step
# Epoch 358/1000
# 4/4 - 2s - loss: 0.0348 - accuracy: 0.7616 - 2s/epoch - 522ms/step
# Epoch 359/1000
# 4/4 - 2s - loss: 0.0348 - accuracy: 0.7759 - 2s/epoch - 551ms/step
# Epoch 360/1000
# 4/4 - 2s - loss: 0.0329 - accuracy: 0.7816 - 2s/epoch - 538ms/step
# Epoch 361/1000
# 4/4 - 2s - loss: 0.0336 - accuracy: 0.7801 - 2s/epoch - 585ms/step
# Epoch 362/1000
# 4/4 - 2s - loss: 0.0328 - accuracy: 0.7840 - 2s/epoch - 557ms/step
# Epoch 363/1000
# 4/4 - 2s - loss: 0.0336 - accuracy: 0.7717 - 2s/epoch - 572ms/step
# Epoch 364/1000
# 4/4 - 2s - loss: 0.0364 - accuracy: 0.7917 - 2s/epoch - 523ms/step
# Epoch 365/1000
# 4/4 - 2s - loss: 0.0345 - accuracy: 0.7710 - 2s/epoch - 561ms/step
# Epoch 366/1000
# 4/4 - 2s - loss: 0.0336 - accuracy: 0.7790 - 2s/epoch - 575ms/step
# Epoch 367/1000
# 4/4 - 2s - loss: 0.0330 - accuracy: 0.7857 - 2s/epoch - 615ms/step
# Epoch 368/1000
# 4/4 - 2s - loss: 0.0341 - accuracy: 0.7744 - 2s/epoch - 599ms/step
# Epoch 369/1000
# 4/4 - 2s - loss: 0.0344 - accuracy: 0.7725 - 2s/epoch - 595ms/step
# Epoch 370/1000
# 4/4 - 2s - loss: 0.0327 - accuracy: 0.7844 - 2s/epoch - 547ms/step
# Epoch 371/1000
# 4/4 - 2s - loss: 0.0328 - accuracy: 0.7781 - 2s/epoch - 530ms/step
# Epoch 372/1000
# 4/4 - 2s - loss: 0.0324 - accuracy: 0.7742 - 2s/epoch - 529ms/step
# Epoch 373/1000
# 4/4 - 2s - loss: 0.0341 - accuracy: 0.7899 - 2s/epoch - 531ms/step
# Epoch 374/1000
# 4/4 - 2s - loss: 0.0337 - accuracy: 0.7919 - 2s/epoch - 528ms/step
# Epoch 375/1000
# 4/4 - 2s - loss: 0.0333 - accuracy: 0.7903 - 2s/epoch - 550ms/step
# Epoch 376/1000
# 4/4 - 2s - loss: 0.0323 - accuracy: 0.7884 - 2s/epoch - 531ms/step
# Epoch 377/1000
# 4/4 - 2s - loss: 0.0316 - accuracy: 0.7964 - 2s/epoch - 555ms/step
# Epoch 378/1000
# 4/4 - 2s - loss: 0.0321 - accuracy: 0.7998 - 2s/epoch - 528ms/step
# Epoch 379/1000
# 4/4 - 2s - loss: 0.0330 - accuracy: 0.7817 - 2s/epoch - 529ms/step
# Epoch 380/1000
# 4/4 - 2s - loss: 0.0325 - accuracy: 0.7761 - 2s/epoch - 527ms/step
# Epoch 381/1000
# 4/4 - 2s - loss: 0.0323 - accuracy: 0.7797 - 2s/epoch - 529ms/step
# Epoch 382/1000
# 4/4 - 2s - loss: 0.0332 - accuracy: 0.7991 - 2s/epoch - 545ms/step
# Epoch 383/1000
# 4/4 - 2s - loss: 0.0332 - accuracy: 0.7777 - 2s/epoch - 561ms/step
# Epoch 384/1000
# 4/4 - 2s - loss: 0.0314 - accuracy: 0.7931 - 2s/epoch - 527ms/step
# Epoch 385/1000
# 4/4 - 2s - loss: 0.0313 - accuracy: 0.7837 - 2s/epoch - 529ms/step
# Epoch 386/1000
# 4/4 - 2s - loss: 0.0316 - accuracy: 0.7877 - 2s/epoch - 528ms/step
# Epoch 387/1000
# 4/4 - 2s - loss: 0.0306 - accuracy: 0.8074 - 2s/epoch - 562ms/step
# Epoch 388/1000
# 4/4 - 2s - loss: 0.0321 - accuracy: 0.7718 - 2s/epoch - 531ms/step
# Epoch 389/1000
# 4/4 - 2s - loss: 0.0317 - accuracy: 0.7828 - 2s/epoch - 534ms/step
# Epoch 390/1000
# 4/4 - 2s - loss: 0.0307 - accuracy: 0.7983 - 2s/epoch - 544ms/step
# Epoch 391/1000
# 4/4 - 2s - loss: 0.0317 - accuracy: 0.7914 - 2s/epoch - 535ms/step
# Epoch 392/1000
# 4/4 - 2s - loss: 0.0308 - accuracy: 0.7702 - 2s/epoch - 544ms/step
# Epoch 393/1000
# 4/4 - 2s - loss: 0.0314 - accuracy: 0.7991 - 2s/epoch - 590ms/step
# Epoch 394/1000
# 4/4 - 2s - loss: 0.0319 - accuracy: 0.7947 - 2s/epoch - 570ms/step
# Epoch 395/1000
# 4/4 - 2s - loss: 0.0319 - accuracy: 0.7971 - 2s/epoch - 569ms/step
# Epoch 396/1000
# 4/4 - 2s - loss: 0.0295 - accuracy: 0.8002 - 2s/epoch - 568ms/step
# Epoch 397/1000
# 4/4 - 2s - loss: 0.0303 - accuracy: 0.7891 - 2s/epoch - 552ms/step
# Epoch 398/1000
# 4/4 - 2s - loss: 0.0308 - accuracy: 0.8068 - 2s/epoch - 547ms/step
# Epoch 399/1000
# 4/4 - 2s - loss: 0.0303 - accuracy: 0.7954 - 2s/epoch - 535ms/step
# Epoch 400/1000
# 4/4 - 2s - loss: 0.0299 - accuracy: 0.8087 - 2s/epoch - 531ms/step
# Epoch 401/1000
# 4/4 - 2s - loss: 0.0299 - accuracy: 0.7973 - 2s/epoch - 540ms/step
# Epoch 402/1000
# 4/4 - 2s - loss: 0.0307 - accuracy: 0.7908 - 2s/epoch - 544ms/step
# Epoch 403/1000
# 4/4 - 2s - loss: 0.0310 - accuracy: 0.8052 - 2s/epoch - 531ms/step
# Epoch 404/1000
# 4/4 - 2s - loss: 0.0285 - accuracy: 0.8075 - 2s/epoch - 554ms/step
# Epoch 405/1000
# 4/4 - 2s - loss: 0.0301 - accuracy: 0.7991 - 2s/epoch - 534ms/step
# Epoch 406/1000
# 4/4 - 2s - loss: 0.0309 - accuracy: 0.7915 - 2s/epoch - 530ms/step
# Epoch 407/1000
# 4/4 - 2s - loss: 0.0293 - accuracy: 0.7996 - 2s/epoch - 554ms/step
# Epoch 408/1000
# 4/4 - 2s - loss: 0.0295 - accuracy: 0.8016 - 2s/epoch - 530ms/step
# Epoch 409/1000
# 4/4 - 2s - loss: 0.0292 - accuracy: 0.7836 - 2s/epoch - 530ms/step
# Epoch 410/1000
# 4/4 - 2s - loss: 0.0308 - accuracy: 0.8040 - 2s/epoch - 533ms/step
# Epoch 411/1000
# 4/4 - 2s - loss: 0.0304 - accuracy: 0.7982 - 2s/epoch - 540ms/step
# Epoch 412/1000
# 4/4 - 2s - loss: 0.0306 - accuracy: 0.8042 - 2s/epoch - 541ms/step
# Epoch 413/1000
# 4/4 - 2s - loss: 0.0287 - accuracy: 0.8137 - 2s/epoch - 541ms/step
# Epoch 414/1000
# 4/4 - 2s - loss: 0.0288 - accuracy: 0.7892 - 2s/epoch - 532ms/step
# Epoch 415/1000
# 4/4 - 2s - loss: 0.0295 - accuracy: 0.8075 - 2s/epoch - 537ms/step
# Epoch 416/1000
# 4/4 - 2s - loss: 0.0285 - accuracy: 0.8068 - 2s/epoch - 543ms/step
# Epoch 417/1000
# 4/4 - 2s - loss: 0.0289 - accuracy: 0.7983 - 2s/epoch - 534ms/step
# Epoch 418/1000
# 4/4 - 2s - loss: 0.0300 - accuracy: 0.8062 - 2s/epoch - 574ms/step
# Epoch 419/1000
# 4/4 - 2s - loss: 0.0291 - accuracy: 0.8080 - 2s/epoch - 553ms/step
# Epoch 420/1000
# 4/4 - 2s - loss: 0.0284 - accuracy: 0.8097 - 2s/epoch - 529ms/step
# Epoch 421/1000
# 4/4 - 2s - loss: 0.0287 - accuracy: 0.8106 - 2s/epoch - 531ms/step
# Epoch 422/1000
# 4/4 - 2s - loss: 0.0297 - accuracy: 0.8010 - 2s/epoch - 542ms/step
# Epoch 423/1000
# 4/4 - 2s - loss: 0.0288 - accuracy: 0.8002 - 2s/epoch - 537ms/step
# Epoch 424/1000
# 4/4 - 2s - loss: 0.0279 - accuracy: 0.8060 - 2s/epoch - 537ms/step
# Epoch 425/1000
# 4/4 - 2s - loss: 0.0279 - accuracy: 0.8101 - 2s/epoch - 530ms/step
# Epoch 426/1000
# 4/4 - 2s - loss: 0.0284 - accuracy: 0.8082 - 2s/epoch - 562ms/step
# Epoch 427/1000
# 4/4 - 2s - loss: 0.0287 - accuracy: 0.8032 - 2s/epoch - 543ms/step
# Epoch 428/1000
# 4/4 - 2s - loss: 0.0282 - accuracy: 0.8000 - 2s/epoch - 555ms/step
# Epoch 429/1000
# 4/4 - 2s - loss: 0.0276 - accuracy: 0.8033 - 2s/epoch - 533ms/step
# Epoch 430/1000
# 4/4 - 2s - loss: 0.0291 - accuracy: 0.8018 - 2s/epoch - 530ms/step
# Epoch 431/1000
# 4/4 - 2s - loss: 0.0276 - accuracy: 0.8211 - 2s/epoch - 544ms/step
# Epoch 432/1000
# 4/4 - 2s - loss: 0.0288 - accuracy: 0.7984 - 2s/epoch - 529ms/step
# Epoch 433/1000
# 4/4 - 2s - loss: 0.0282 - accuracy: 0.7974 - 2s/epoch - 541ms/step
# Epoch 434/1000
# 4/4 - 2s - loss: 0.0273 - accuracy: 0.8227 - 2s/epoch - 545ms/step
# Epoch 435/1000
# 4/4 - 2s - loss: 0.0274 - accuracy: 0.8082 - 2s/epoch - 526ms/step
# Epoch 436/1000
# 4/4 - 2s - loss: 0.0283 - accuracy: 0.7878 - 2s/epoch - 541ms/step
# Epoch 437/1000
# 4/4 - 2s - loss: 0.0276 - accuracy: 0.8079 - 2s/epoch - 529ms/step
# Epoch 438/1000
# 4/4 - 2s - loss: 0.0272 - accuracy: 0.8170 - 2s/epoch - 560ms/step
# Epoch 439/1000
# 4/4 - 2s - loss: 0.0287 - accuracy: 0.8209 - 2s/epoch - 530ms/step
# Epoch 440/1000
# 4/4 - 2s - loss: 0.0272 - accuracy: 0.8148 - 2s/epoch - 530ms/step
# Epoch 441/1000
# 4/4 - 2s - loss: 0.0270 - accuracy: 0.8240 - 2s/epoch - 568ms/step
# Epoch 442/1000
# 4/4 - 2s - loss: 0.0272 - accuracy: 0.8074 - 2s/epoch - 532ms/step
# Epoch 443/1000
# 4/4 - 2s - loss: 0.0293 - accuracy: 0.7958 - 2s/epoch - 536ms/step
# Epoch 444/1000
# 4/4 - 2s - loss: 0.0276 - accuracy: 0.7939 - 2s/epoch - 527ms/step
# Epoch 445/1000
# 4/4 - 2s - loss: 0.0272 - accuracy: 0.8076 - 2s/epoch - 534ms/step
# Epoch 446/1000
# 4/4 - 2s - loss: 0.0266 - accuracy: 0.8107 - 2s/epoch - 530ms/step
# Epoch 447/1000
# 4/4 - 2s - loss: 0.0266 - accuracy: 0.8171 - 2s/epoch - 530ms/step
# Epoch 448/1000
# 4/4 - 2s - loss: 0.0270 - accuracy: 0.8081 - 2s/epoch - 572ms/step
# Epoch 449/1000
# 4/4 - 2s - loss: 0.0268 - accuracy: 0.8137 - 2s/epoch - 543ms/step
# Epoch 450/1000
# 4/4 - 2s - loss: 0.0276 - accuracy: 0.8196 - 2s/epoch - 530ms/step
# Epoch 451/1000
# 4/4 - 2s - loss: 0.0269 - accuracy: 0.8231 - 2s/epoch - 530ms/step
# Epoch 452/1000
# 4/4 - 2s - loss: 0.0262 - accuracy: 0.8034 - 2s/epoch - 527ms/step
# Epoch 453/1000
# 4/4 - 2s - loss: 0.0270 - accuracy: 0.8074 - 2s/epoch - 533ms/step
# Epoch 454/1000
# 4/4 - 2s - loss: 0.0264 - accuracy: 0.8160 - 2s/epoch - 528ms/step
# Epoch 455/1000
# 4/4 - 2s - loss: 0.0264 - accuracy: 0.8162 - 2s/epoch - 536ms/step
# Epoch 456/1000
# 4/4 - 2s - loss: 0.0267 - accuracy: 0.8170 - 2s/epoch - 548ms/step
# Epoch 457/1000
# 4/4 - 2s - loss: 0.0264 - accuracy: 0.8040 - 2s/epoch - 532ms/step
# Epoch 458/1000
# 4/4 - 2s - loss: 0.0264 - accuracy: 0.8189 - 2s/epoch - 528ms/step
# Epoch 459/1000
# 4/4 - 2s - loss: 0.0266 - accuracy: 0.8159 - 2s/epoch - 561ms/step
# Epoch 460/1000
# 4/4 - 2s - loss: 0.0263 - accuracy: 0.8154 - 2s/epoch - 531ms/step
# Epoch 461/1000
# 4/4 - 2s - loss: 0.0261 - accuracy: 0.8157 - 2s/epoch - 542ms/step
# Epoch 462/1000
# 4/4 - 2s - loss: 0.0262 - accuracy: 0.8105 - 2s/epoch - 527ms/step
# Epoch 463/1000
# 4/4 - 2s - loss: 0.0262 - accuracy: 0.8220 - 2s/epoch - 544ms/step
# Epoch 464/1000
# 4/4 - 2s - loss: 0.0264 - accuracy: 0.8072 - 2s/epoch - 534ms/step
# Epoch 465/1000
# 4/4 - 2s - loss: 0.0260 - accuracy: 0.8070 - 2s/epoch - 528ms/step
# Epoch 466/1000
# 4/4 - 2s - loss: 0.0259 - accuracy: 0.8161 - 2s/epoch - 532ms/step
# Epoch 467/1000
# 4/4 - 2s - loss: 0.0256 - accuracy: 0.8271 - 2s/epoch - 527ms/step
# Epoch 468/1000
# 4/4 - 2s - loss: 0.0254 - accuracy: 0.8230 - 2s/epoch - 533ms/step
# Epoch 469/1000
# 4/4 - 2s - loss: 0.0249 - accuracy: 0.8297 - 2s/epoch - 556ms/step
# Epoch 470/1000
# 4/4 - 2s - loss: 0.0251 - accuracy: 0.8175 - 2s/epoch - 544ms/step
# Epoch 471/1000
# 4/4 - 2s - loss: 0.0267 - accuracy: 0.8150 - 2s/epoch - 564ms/step
# Epoch 472/1000
# 4/4 - 2s - loss: 0.0269 - accuracy: 0.8090 - 2s/epoch - 525ms/step
# Epoch 473/1000
# 4/4 - 2s - loss: 0.0254 - accuracy: 0.8126 - 2s/epoch - 551ms/step
# Epoch 474/1000
# 4/4 - 2s - loss: 0.0263 - accuracy: 0.8174 - 2s/epoch - 531ms/step
# Epoch 475/1000
# 4/4 - 2s - loss: 0.0251 - accuracy: 0.8249 - 2s/epoch - 527ms/step
# Epoch 476/1000
# 4/4 - 2s - loss: 0.0252 - accuracy: 0.8286 - 2s/epoch - 533ms/step
# Epoch 477/1000
# 4/4 - 2s - loss: 0.0243 - accuracy: 0.8194 - 2s/epoch - 526ms/step
# Epoch 478/1000
# 4/4 - 2s - loss: 0.0243 - accuracy: 0.8251 - 2s/epoch - 555ms/step
# Epoch 479/1000
# 4/4 - 2s - loss: 0.0247 - accuracy: 0.8234 - 2s/epoch - 579ms/step
# Epoch 480/1000
# 4/4 - 2s - loss: 0.0258 - accuracy: 0.8168 - 2s/epoch - 540ms/step
# Epoch 481/1000
# 4/4 - 2s - loss: 0.0251 - accuracy: 0.8195 - 2s/epoch - 528ms/step
# Epoch 482/1000
# 4/4 - 2s - loss: 0.0259 - accuracy: 0.8170 - 2s/epoch - 533ms/step
# Epoch 483/1000
# 4/4 - 2s - loss: 0.0265 - accuracy: 0.8132 - 2s/epoch - 533ms/step
# Epoch 484/1000
# 4/4 - 2s - loss: 0.0244 - accuracy: 0.8189 - 2s/epoch - 531ms/step
# Epoch 485/1000
# 4/4 - 2s - loss: 0.0248 - accuracy: 0.8216 - 2s/epoch - 544ms/step
# Epoch 486/1000
# 4/4 - 2s - loss: 0.0245 - accuracy: 0.8158 - 2s/epoch - 549ms/step
# Epoch 487/1000
# 4/4 - 2s - loss: 0.0257 - accuracy: 0.8221 - 2s/epoch - 544ms/step
# Epoch 488/1000
# 4/4 - 2s - loss: 0.0256 - accuracy: 0.8149 - 2s/epoch - 537ms/step
# Epoch 489/1000
# 4/4 - 2s - loss: 0.0250 - accuracy: 0.8145 - 2s/epoch - 540ms/step
# Epoch 490/1000
# 4/4 - 2s - loss: 0.0245 - accuracy: 0.8277 - 2s/epoch - 543ms/step
# Epoch 491/1000
# 4/4 - 2s - loss: 0.0246 - accuracy: 0.8321 - 2s/epoch - 527ms/step
# Epoch 492/1000
# 4/4 - 2s - loss: 0.0244 - accuracy: 0.8240 - 2s/epoch - 534ms/step
# Epoch 493/1000
# 4/4 - 2s - loss: 0.0239 - accuracy: 0.8275 - 2s/epoch - 566ms/step
# Epoch 494/1000
# 4/4 - 2s - loss: 0.0244 - accuracy: 0.8118 - 2s/epoch - 533ms/step
# Epoch 495/1000
# 4/4 - 2s - loss: 0.0250 - accuracy: 0.8246 - 2s/epoch - 542ms/step
# Epoch 496/1000
# 4/4 - 2s - loss: 0.0249 - accuracy: 0.8252 - 2s/epoch - 531ms/step
# Epoch 497/1000
# 4/4 - 2s - loss: 0.0240 - accuracy: 0.8118 - 2s/epoch - 530ms/step
# Epoch 498/1000
# 4/4 - 2s - loss: 0.0242 - accuracy: 0.8260 - 2s/epoch - 543ms/step
# Epoch 499/1000
# 4/4 - 2s - loss: 0.0243 - accuracy: 0.8264 - 2s/epoch - 530ms/step
# Epoch 500/1000
# 4/4 - 2s - loss: 0.0245 - accuracy: 0.8192 - 2s/epoch - 593ms/step
# Epoch 501/1000
# 4/4 - 2s - loss: 0.0246 - accuracy: 0.8074 - 2s/epoch - 535ms/step
# Epoch 502/1000
# 4/4 - 2s - loss: 0.0242 - accuracy: 0.8230 - 2s/epoch - 526ms/step
# Epoch 503/1000
# 4/4 - 2s - loss: 0.0236 - accuracy: 0.8306 - 2s/epoch - 570ms/step
# Epoch 504/1000
# 4/4 - 3s - loss: 0.0244 - accuracy: 0.8375 - 3s/epoch - 648ms/step
# Epoch 505/1000
# 4/4 - 2s - loss: 0.0238 - accuracy: 0.8247 - 2s/epoch - 601ms/step
# Epoch 506/1000
# 4/4 - 2s - loss: 0.0240 - accuracy: 0.8373 - 2s/epoch - 574ms/step
# Epoch 507/1000
# 4/4 - 2s - loss: 0.0239 - accuracy: 0.8206 - 2s/epoch - 595ms/step
# Epoch 508/1000
# 4/4 - 2s - loss: 0.0235 - accuracy: 0.8228 - 2s/epoch - 562ms/step
# Epoch 509/1000
# 4/4 - 2s - loss: 0.0247 - accuracy: 0.8288 - 2s/epoch - 550ms/step
# Epoch 510/1000
# 4/4 - 2s - loss: 0.0240 - accuracy: 0.8193 - 2s/epoch - 524ms/step
# Epoch 511/1000
# 4/4 - 2s - loss: 0.0235 - accuracy: 0.8277 - 2s/epoch - 535ms/step
# Epoch 512/1000
# 4/4 - 2s - loss: 0.0241 - accuracy: 0.8168 - 2s/epoch - 535ms/step
# Epoch 513/1000
# 4/4 - 2s - loss: 0.0241 - accuracy: 0.8310 - 2s/epoch - 527ms/step
# Epoch 514/1000
# 4/4 - 2s - loss: 0.0243 - accuracy: 0.8309 - 2s/epoch - 546ms/step
# Epoch 515/1000
# 4/4 - 2s - loss: 0.0237 - accuracy: 0.8111 - 2s/epoch - 544ms/step
# Epoch 516/1000
# 4/4 - 2s - loss: 0.0235 - accuracy: 0.8218 - 2s/epoch - 531ms/step
# Epoch 517/1000
# 4/4 - 2s - loss: 0.0232 - accuracy: 0.8259 - 2s/epoch - 525ms/step
# Epoch 518/1000
# 4/4 - 2s - loss: 0.0240 - accuracy: 0.8283 - 2s/epoch - 543ms/step
# Epoch 519/1000
# 4/4 - 2s - loss: 0.0238 - accuracy: 0.8366 - 2s/epoch - 581ms/step
# Epoch 520/1000
# 4/4 - 2s - loss: 0.0231 - accuracy: 0.8220 - 2s/epoch - 538ms/step
# Epoch 521/1000
# 4/4 - 2s - loss: 0.0238 - accuracy: 0.8198 - 2s/epoch - 542ms/step
# Epoch 522/1000
# 4/4 - 2s - loss: 0.0238 - accuracy: 0.8299 - 2s/epoch - 554ms/step
# Epoch 523/1000
# 4/4 - 2s - loss: 0.0232 - accuracy: 0.8299 - 2s/epoch - 530ms/step
# Epoch 524/1000
# 4/4 - 2s - loss: 0.0229 - accuracy: 0.8285 - 2s/epoch - 526ms/step
# Epoch 525/1000
# 4/4 - 2s - loss: 0.0229 - accuracy: 0.8326 - 2s/epoch - 538ms/step
# Epoch 526/1000
# 4/4 - 2s - loss: 0.0233 - accuracy: 0.8160 - 2s/epoch - 539ms/step
# Epoch 527/1000
# 4/4 - 2s - loss: 0.0233 - accuracy: 0.8323 - 2s/epoch - 537ms/step
# Epoch 528/1000
# 4/4 - 2s - loss: 0.0238 - accuracy: 0.8287 - 2s/epoch - 540ms/step
# Epoch 529/1000
# 4/4 - 2s - loss: 0.0233 - accuracy: 0.8173 - 2s/epoch - 582ms/step
# Epoch 530/1000
# 4/4 - 2s - loss: 0.0228 - accuracy: 0.8312 - 2s/epoch - 533ms/step
# Epoch 531/1000
# 4/4 - 2s - loss: 0.0231 - accuracy: 0.8292 - 2s/epoch - 527ms/step
# Epoch 532/1000
# 4/4 - 2s - loss: 0.0233 - accuracy: 0.8334 - 2s/epoch - 535ms/step
# Epoch 533/1000
# 4/4 - 2s - loss: 0.0228 - accuracy: 0.8364 - 2s/epoch - 535ms/step
# Epoch 534/1000
# 4/4 - 2s - loss: 0.0217 - accuracy: 0.8333 - 2s/epoch - 533ms/step
# Epoch 535/1000
# 4/4 - 2s - loss: 0.0221 - accuracy: 0.8364 - 2s/epoch - 533ms/step
# Epoch 536/1000
# 4/4 - 2s - loss: 0.0240 - accuracy: 0.8321 - 2s/epoch - 542ms/step
# Epoch 537/1000
# 4/4 - 2s - loss: 0.0233 - accuracy: 0.8293 - 2s/epoch - 541ms/step
# Epoch 538/1000
# 4/4 - 2s - loss: 0.0227 - accuracy: 0.8327 - 2s/epoch - 546ms/step
# Epoch 539/1000
# 4/4 - 2s - loss: 0.0229 - accuracy: 0.8194 - 2s/epoch - 533ms/step
# Epoch 540/1000
# 4/4 - 2s - loss: 0.0229 - accuracy: 0.8370 - 2s/epoch - 560ms/step
# Epoch 541/1000
# 4/4 - 2s - loss: 0.0229 - accuracy: 0.8365 - 2s/epoch - 536ms/step
# Epoch 542/1000
# 4/4 - 2s - loss: 0.0226 - accuracy: 0.8307 - 2s/epoch - 532ms/step
# Epoch 543/1000
# 4/4 - 2s - loss: 0.0226 - accuracy: 0.8414 - 2s/epoch - 535ms/step
# Epoch 544/1000
# 4/4 - 2s - loss: 0.0221 - accuracy: 0.8255 - 2s/epoch - 550ms/step
# Epoch 545/1000
# 4/4 - 2s - loss: 0.0232 - accuracy: 0.8397 - 2s/epoch - 531ms/step
# Epoch 546/1000
# 4/4 - 2s - loss: 0.0235 - accuracy: 0.8313 - 2s/epoch - 529ms/step
# Epoch 547/1000
# 4/4 - 2s - loss: 0.0219 - accuracy: 0.8294 - 2s/epoch - 528ms/step
# Epoch 548/1000
# 4/4 - 2s - loss: 0.0217 - accuracy: 0.8357 - 2s/epoch - 528ms/step
# Epoch 549/1000
# 4/4 - 2s - loss: 0.0228 - accuracy: 0.8354 - 2s/epoch - 532ms/step
# Epoch 550/1000
# 4/4 - 2s - loss: 0.0230 - accuracy: 0.8325 - 2s/epoch - 557ms/step
# Epoch 551/1000
# 4/4 - 2s - loss: 0.0224 - accuracy: 0.8317 - 2s/epoch - 546ms/step
# Epoch 552/1000
# 4/4 - 2s - loss: 0.0221 - accuracy: 0.8302 - 2s/epoch - 543ms/step
# Epoch 553/1000
# 4/4 - 2s - loss: 0.0225 - accuracy: 0.8422 - 2s/epoch - 536ms/step
# Epoch 554/1000
# 4/4 - 2s - loss: 0.0227 - accuracy: 0.8372 - 2s/epoch - 528ms/step
# Epoch 555/1000
# 4/4 - 2s - loss: 0.0218 - accuracy: 0.8279 - 2s/epoch - 533ms/step
# Epoch 556/1000
# 4/4 - 2s - loss: 0.0221 - accuracy: 0.8285 - 2s/epoch - 530ms/step
# Epoch 557/1000
# 4/4 - 2s - loss: 0.0228 - accuracy: 0.8184 - 2s/epoch - 545ms/step
# Epoch 558/1000
# 4/4 - 2s - loss: 0.0229 - accuracy: 0.8357 - 2s/epoch - 543ms/step
# Epoch 559/1000
# 4/4 - 2s - loss: 0.0224 - accuracy: 0.8301 - 2s/epoch - 539ms/step
# Epoch 560/1000
# 4/4 - 2s - loss: 0.0218 - accuracy: 0.8276 - 2s/epoch - 549ms/step
# Epoch 561/1000
# 4/4 - 2s - loss: 0.0221 - accuracy: 0.8363 - 2s/epoch - 549ms/step
# Epoch 562/1000
# 4/4 - 2s - loss: 0.0219 - accuracy: 0.8399 - 2s/epoch - 531ms/step
# Epoch 563/1000
# 4/4 - 2s - loss: 0.0217 - accuracy: 0.8372 - 2s/epoch - 530ms/step
# Epoch 564/1000
# 4/4 - 2s - loss: 0.0219 - accuracy: 0.8380 - 2s/epoch - 529ms/step
# Epoch 565/1000
# 4/4 - 2s - loss: 0.0221 - accuracy: 0.8257 - 2s/epoch - 531ms/step
# Epoch 566/1000
# 4/4 - 2s - loss: 0.0223 - accuracy: 0.8463 - 2s/epoch - 551ms/step
# Epoch 567/1000
# 4/4 - 2s - loss: 0.0221 - accuracy: 0.8376 - 2s/epoch - 531ms/step
# Epoch 568/1000
# 4/4 - 2s - loss: 0.0215 - accuracy: 0.8321 - 2s/epoch - 530ms/step
# Epoch 569/1000
# 4/4 - 2s - loss: 0.0218 - accuracy: 0.8246 - 2s/epoch - 531ms/step
# Epoch 570/1000
# 4/4 - 2s - loss: 0.0220 - accuracy: 0.8327 - 2s/epoch - 532ms/step
# Epoch 571/1000
# 4/4 - 2s - loss: 0.0222 - accuracy: 0.8468 - 2s/epoch - 555ms/step
# Epoch 572/1000
# 4/4 - 2s - loss: 0.0222 - accuracy: 0.8450 - 2s/epoch - 530ms/step
# Epoch 573/1000
# 4/4 - 2s - loss: 0.0209 - accuracy: 0.8413 - 2s/epoch - 544ms/step
# Epoch 574/1000
# 4/4 - 2s - loss: 0.0213 - accuracy: 0.8417 - 2s/epoch - 542ms/step
# Epoch 575/1000
# 4/4 - 2s - loss: 0.0222 - accuracy: 0.8224 - 2s/epoch - 524ms/step
# Epoch 576/1000
# 4/4 - 2s - loss: 0.0220 - accuracy: 0.8343 - 2s/epoch - 531ms/step
# Epoch 577/1000
# 4/4 - 2s - loss: 0.0221 - accuracy: 0.8407 - 2s/epoch - 543ms/step
# Epoch 578/1000
# 4/4 - 2s - loss: 0.0219 - accuracy: 0.8433 - 2s/epoch - 534ms/step
# Epoch 579/1000
# 4/4 - 2s - loss: 0.0212 - accuracy: 0.8334 - 2s/epoch - 530ms/step
# Epoch 580/1000
# 4/4 - 2s - loss: 0.0213 - accuracy: 0.8389 - 2s/epoch - 533ms/step
# Epoch 581/1000
# 4/4 - 2s - loss: 0.0216 - accuracy: 0.8381 - 2s/epoch - 596ms/step
# Epoch 582/1000
# 4/4 - 2s - loss: 0.0214 - accuracy: 0.8379 - 2s/epoch - 530ms/step
# Epoch 583/1000
# 4/4 - 2s - loss: 0.0213 - accuracy: 0.8368 - 2s/epoch - 534ms/step
# Epoch 584/1000
# 4/4 - 2s - loss: 0.0215 - accuracy: 0.8407 - 2s/epoch - 548ms/step
# Epoch 585/1000
# 4/4 - 2s - loss: 0.0220 - accuracy: 0.8400 - 2s/epoch - 526ms/step
# Epoch 586/1000
# 4/4 - 2s - loss: 0.0219 - accuracy: 0.8419 - 2s/epoch - 530ms/step
# Epoch 587/1000
# ...
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8743 - 2s/epoch - 497ms/step
# Epoch 807/1000
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.8637 - 2s/epoch - 491ms/step
# Epoch 808/1000
# 4/4 - 2s - loss: 0.0187 - accuracy: 0.8615 - 2s/epoch - 516ms/step
# Epoch 809/1000
# 4/4 - 2s - loss: 0.0192 - accuracy: 0.8521 - 2s/epoch - 495ms/step
# Epoch 810/1000
# 4/4 - 2s - loss: 0.0190 - accuracy: 0.8512 - 2s/epoch - 505ms/step
# Epoch 811/1000
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.8688 - 2s/epoch - 510ms/step
# Epoch 812/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8673 - 2s/epoch - 495ms/step
# Epoch 813/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8741 - 2s/epoch - 500ms/step
# Epoch 814/1000
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.8708 - 2s/epoch - 498ms/step
# Epoch 815/1000
# 4/4 - 2s - loss: 0.0185 - accuracy: 0.8520 - 2s/epoch - 508ms/step
# Epoch 816/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8661 - 2s/epoch - 537ms/step
# Epoch 817/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8690 - 2s/epoch - 498ms/step
# Epoch 818/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8700 - 2s/epoch - 511ms/step
# Epoch 819/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8718 - 2s/epoch - 498ms/step
# Epoch 820/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8680 - 2s/epoch - 500ms/step
# Epoch 821/1000
# 4/4 - 2s - loss: 0.0193 - accuracy: 0.8562 - 2s/epoch - 504ms/step
# Epoch 822/1000
# 4/4 - 2s - loss: 0.0190 - accuracy: 0.8494 - 2s/epoch - 498ms/step
# Epoch 823/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8598 - 2s/epoch - 494ms/step
# Epoch 824/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8734 - 2s/epoch - 505ms/step
# Epoch 825/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8712 - 2s/epoch - 490ms/step
# Epoch 826/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8605 - 2s/epoch - 487ms/step
# Epoch 827/1000
# 4/4 - 2s - loss: 0.0187 - accuracy: 0.8708 - 2s/epoch - 482ms/step
# Epoch 828/1000
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.8530 - 2s/epoch - 485ms/step
# Epoch 829/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8751 - 2s/epoch - 487ms/step
# Epoch 830/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8619 - 2s/epoch - 486ms/step
# Epoch 831/1000
# 4/4 - 2s - loss: 0.0185 - accuracy: 0.8658 - 2s/epoch - 488ms/step
# Epoch 832/1000
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.8575 - 2s/epoch - 507ms/step
# Epoch 833/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8757 - 2s/epoch - 511ms/step
# Epoch 834/1000
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.8727 - 2s/epoch - 484ms/step
# Epoch 835/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8703 - 2s/epoch - 489ms/step
# Epoch 836/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8759 - 2s/epoch - 489ms/step
# Epoch 837/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8630 - 2s/epoch - 486ms/step
# Epoch 838/1000
# 4/4 - 2s - loss: 0.0189 - accuracy: 0.8633 - 2s/epoch - 484ms/step
# Epoch 839/1000
# 4/4 - 2s - loss: 0.0186 - accuracy: 0.8708 - 2s/epoch - 488ms/step
# Epoch 840/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8656 - 2s/epoch - 506ms/step
# Epoch 841/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8762 - 2s/epoch - 490ms/step
# Epoch 842/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8624 - 2s/epoch - 488ms/step
# Epoch 843/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8742 - 2s/epoch - 486ms/step
# Epoch 844/1000
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.8721 - 2s/epoch - 511ms/step
# Epoch 845/1000
# 4/4 - 2s - loss: 0.0185 - accuracy: 0.8580 - 2s/epoch - 485ms/step
# Epoch 846/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8761 - 2s/epoch - 495ms/step
# Epoch 847/1000
# 4/4 - 2s - loss: 0.0187 - accuracy: 0.8662 - 2s/epoch - 488ms/step
# Epoch 848/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8690 - 2s/epoch - 510ms/step
# Epoch 849/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8740 - 2s/epoch - 487ms/step
# Epoch 850/1000
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.8632 - 2s/epoch - 486ms/step
# Epoch 851/1000
# 4/4 - 2s - loss: 0.0189 - accuracy: 0.8721 - 2s/epoch - 484ms/step
# Epoch 852/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8755 - 2s/epoch - 487ms/step
# Epoch 853/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8689 - 2s/epoch - 484ms/step
# Epoch 854/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8826 - 2s/epoch - 493ms/step
# Epoch 855/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8640 - 2s/epoch - 496ms/step
# Epoch 856/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8775 - 2s/epoch - 517ms/step
# Epoch 857/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8651 - 2s/epoch - 491ms/step
# Epoch 858/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8718 - 2s/epoch - 490ms/step
# Epoch 859/1000
# 4/4 - 2s - loss: 0.0193 - accuracy: 0.8641 - 2s/epoch - 486ms/step
# Epoch 860/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8652 - 2s/epoch - 485ms/step
# Epoch 861/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8651 - 2s/epoch - 489ms/step
# Epoch 862/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8705 - 2s/epoch - 485ms/step
# Epoch 863/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8757 - 2s/epoch - 486ms/step
# Epoch 864/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8684 - 2s/epoch - 504ms/step
# Epoch 865/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8847 - 2s/epoch - 493ms/step
# Epoch 866/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8635 - 2s/epoch - 485ms/step
# Epoch 867/1000
# 4/4 - 2s - loss: 0.0192 - accuracy: 0.8687 - 2s/epoch - 514ms/step
# Epoch 868/1000
# 4/4 - 2s - loss: 0.0185 - accuracy: 0.8702 - 2s/epoch - 490ms/step
# Epoch 869/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8680 - 2s/epoch - 485ms/step
# Epoch 870/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8844 - 2s/epoch - 486ms/step
# Epoch 871/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8692 - 2s/epoch - 485ms/step
# Epoch 872/1000
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.8673 - 2s/epoch - 499ms/step
# Epoch 873/1000
# 4/4 - 2s - loss: 0.0186 - accuracy: 0.8681 - 2s/epoch - 498ms/step
# Epoch 874/1000
# 4/4 - 2s - loss: 0.0186 - accuracy: 0.8721 - 2s/epoch - 486ms/step
# Epoch 875/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8693 - 2s/epoch - 492ms/step
# Epoch 876/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8736 - 2s/epoch - 504ms/step
# Epoch 877/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8728 - 2s/epoch - 488ms/step
# Epoch 878/1000
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.8631 - 2s/epoch - 509ms/step
# Epoch 879/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8716 - 2s/epoch - 501ms/step
# Epoch 880/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8639 - 2s/epoch - 500ms/step
# Epoch 881/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8827 - 2s/epoch - 497ms/step
# Epoch 882/1000
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.8556 - 2s/epoch - 486ms/step
# Epoch 883/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8797 - 2s/epoch - 485ms/step
# Epoch 884/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8715 - 2s/epoch - 491ms/step
# Epoch 885/1000
# 4/4 - 2s - loss: 0.0185 - accuracy: 0.8662 - 2s/epoch - 486ms/step
# Epoch 886/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8759 - 2s/epoch - 483ms/step
# Epoch 887/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8664 - 2s/epoch - 489ms/step
# Epoch 888/1000
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.8725 - 2s/epoch - 495ms/step
# Epoch 889/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8746 - 2s/epoch - 524ms/step
# Epoch 890/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8704 - 2s/epoch - 485ms/step
# Epoch 891/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8765 - 2s/epoch - 487ms/step
# Epoch 892/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8642 - 2s/epoch - 490ms/step
# Epoch 893/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8770 - 2s/epoch - 485ms/step
# Epoch 894/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8767 - 2s/epoch - 490ms/step
# Epoch 895/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8701 - 2s/epoch - 489ms/step
# Epoch 896/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8668 - 2s/epoch - 500ms/step
# Epoch 897/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8642 - 2s/epoch - 497ms/step
# Epoch 898/1000
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.8774 - 2s/epoch - 484ms/step
# Epoch 899/1000
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.8817 - 2s/epoch - 489ms/step
# Epoch 900/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8734 - 2s/epoch - 493ms/step
# Epoch 901/1000
# 4/4 - 2s - loss: 0.0170 - accuracy: 0.8790 - 2s/epoch - 502ms/step
# Epoch 902/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8733 - 2s/epoch - 488ms/step
# Epoch 903/1000
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.8617 - 2s/epoch - 486ms/step
# Epoch 904/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8664 - 2s/epoch - 496ms/step
# Epoch 905/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8695 - 2s/epoch - 498ms/step
# Epoch 906/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8744 - 2s/epoch - 489ms/step
# Epoch 907/1000
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.8775 - 2s/epoch - 494ms/step
# Epoch 908/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8698 - 2s/epoch - 488ms/step
# Epoch 909/1000
# 4/4 - 2s - loss: 0.0171 - accuracy: 0.8679 - 2s/epoch - 488ms/step
# Epoch 910/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8806 - 2s/epoch - 484ms/step
# Epoch 911/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8620 - 2s/epoch - 486ms/step
# Epoch 912/1000
# 4/4 - 2s - loss: 0.0186 - accuracy: 0.8784 - 2s/epoch - 520ms/step
# Epoch 913/1000
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.8753 - 2s/epoch - 503ms/step
# Epoch 914/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8740 - 2s/epoch - 494ms/step
# Epoch 915/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8799 - 2s/epoch - 490ms/step
# Epoch 916/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8734 - 2s/epoch - 480ms/step
# Epoch 917/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8818 - 2s/epoch - 486ms/step
# Epoch 918/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8672 - 2s/epoch - 482ms/step
# Epoch 919/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8752 - 2s/epoch - 489ms/step
# Epoch 920/1000
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.8745 - 2s/epoch - 493ms/step
# Epoch 921/1000
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.8593 - 2s/epoch - 505ms/step
# Epoch 922/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8783 - 2s/epoch - 488ms/step
# Epoch 923/1000
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.8760 - 2s/epoch - 522ms/step
# Epoch 924/1000
# 4/4 - 2s - loss: 0.0171 - accuracy: 0.8791 - 2s/epoch - 486ms/step
# Epoch 925/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8820 - 2s/epoch - 488ms/step
# Epoch 926/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8610 - 2s/epoch - 486ms/step
# Epoch 927/1000
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.8789 - 2s/epoch - 491ms/step
# Epoch 928/1000
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.8735 - 2s/epoch - 501ms/step
# Epoch 929/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8751 - 2s/epoch - 527ms/step
# Epoch 930/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8812 - 2s/epoch - 497ms/step
# Epoch 931/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8702 - 2s/epoch - 497ms/step
# Epoch 932/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8850 - 2s/epoch - 483ms/step
# Epoch 933/1000
# 4/4 - 2s - loss: 0.0171 - accuracy: 0.8730 - 2s/epoch - 487ms/step
# Epoch 934/1000
# 4/4 - 2s - loss: 0.0180 - accuracy: 0.8727 - 2s/epoch - 512ms/step
# Epoch 935/1000
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.8686 - 2s/epoch - 491ms/step
# Epoch 936/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8673 - 2s/epoch - 500ms/step
# Epoch 937/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8792 - 2s/epoch - 519ms/step
# Epoch 938/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8800 - 2s/epoch - 488ms/step
# Epoch 939/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8787 - 2s/epoch - 497ms/step
# Epoch 940/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8798 - 2s/epoch - 484ms/step
# Epoch 941/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8596 - 2s/epoch - 492ms/step
# Epoch 942/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8798 - 2s/epoch - 486ms/step
# Epoch 943/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8752 - 2s/epoch - 486ms/step
# Epoch 944/1000
# 4/4 - 2s - loss: 0.0171 - accuracy: 0.8739 - 2s/epoch - 490ms/step
# Epoch 945/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8819 - 2s/epoch - 522ms/step
# Epoch 946/1000
# 4/4 - 2s - loss: 0.0170 - accuracy: 0.8727 - 2s/epoch - 500ms/step
# Epoch 947/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8841 - 2s/epoch - 486ms/step
# Epoch 948/1000
# 4/4 - 2s - loss: 0.0184 - accuracy: 0.8656 - 2s/epoch - 481ms/step
# Epoch 949/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8810 - 2s/epoch - 486ms/step
# Epoch 950/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8725 - 2s/epoch - 491ms/step
# Epoch 951/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8747 - 2s/epoch - 487ms/step
# Epoch 952/1000
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.8771 - 2s/epoch - 491ms/step
# Epoch 953/1000
# 4/4 - 2s - loss: 0.0182 - accuracy: 0.8774 - 2s/epoch - 507ms/step
# Epoch 954/1000
# 4/4 - 2s - loss: 0.0171 - accuracy: 0.8750 - 2s/epoch - 487ms/step
# Epoch 955/1000
# 4/4 - 2s - loss: 0.0169 - accuracy: 0.8871 - 2s/epoch - 485ms/step
# Epoch 956/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8759 - 2s/epoch - 485ms/step
# Epoch 957/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8735 - 2s/epoch - 514ms/step
# Epoch 958/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8762 - 2s/epoch - 488ms/step
# Epoch 959/1000
# 4/4 - 2s - loss: 0.0170 - accuracy: 0.8717 - 2s/epoch - 488ms/step
# Epoch 960/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8791 - 2s/epoch - 489ms/step
# Epoch 961/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8710 - 2s/epoch - 510ms/step
# Epoch 962/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8853 - 2s/epoch - 490ms/step
# Epoch 963/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8706 - 2s/epoch - 485ms/step
# Epoch 964/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8827 - 2s/epoch - 489ms/step
# Epoch 965/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8771 - 2s/epoch - 486ms/step
# Epoch 966/1000
# 4/4 - 2s - loss: 0.0171 - accuracy: 0.8745 - 2s/epoch - 483ms/step
# Epoch 967/1000
# 4/4 - 2s - loss: 0.0170 - accuracy: 0.8854 - 2s/epoch - 493ms/step
# Epoch 968/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8694 - 2s/epoch - 511ms/step
# Epoch 969/1000
# 4/4 - 2s - loss: 0.0183 - accuracy: 0.8792 - 2s/epoch - 507ms/step
# Epoch 970/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8768 - 2s/epoch - 486ms/step
# Epoch 971/1000
# 4/4 - 2s - loss: 0.0169 - accuracy: 0.8740 - 2s/epoch - 488ms/step
# Epoch 972/1000
# 4/4 - 2s - loss: 0.0168 - accuracy: 0.8850 - 2s/epoch - 487ms/step
# Epoch 973/1000
# 4/4 - 2s - loss: 0.0171 - accuracy: 0.8729 - 2s/epoch - 483ms/step
# Epoch 974/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8785 - 2s/epoch - 489ms/step
# Epoch 975/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8655 - 2s/epoch - 493ms/step
# Epoch 976/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8842 - 2s/epoch - 488ms/step
# Epoch 977/1000
# 4/4 - 2s - loss: 0.0178 - accuracy: 0.8750 - 2s/epoch - 505ms/step
# Epoch 978/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8779 - 2s/epoch - 489ms/step
# Epoch 979/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8812 - 2s/epoch - 510ms/step
# Epoch 980/1000
# 4/4 - 2s - loss: 0.0168 - accuracy: 0.8744 - 2s/epoch - 487ms/step
# Epoch 981/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8746 - 2s/epoch - 494ms/step
# Epoch 982/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8803 - 2s/epoch - 488ms/step
# Epoch 983/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8706 - 2s/epoch - 487ms/step
# Epoch 984/1000
# 4/4 - 2s - loss: 0.0181 - accuracy: 0.8790 - 2s/epoch - 486ms/step
# Epoch 985/1000
# 4/4 - 2s - loss: 0.0172 - accuracy: 0.8822 - 2s/epoch - 505ms/step
# Epoch 986/1000
# 4/4 - 2s - loss: 0.0167 - accuracy: 0.8739 - 2s/epoch - 492ms/step
# Epoch 987/1000
# 4/4 - 2s - loss: 0.0170 - accuracy: 0.8837 - 2s/epoch - 489ms/step
# Epoch 988/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8768 - 2s/epoch - 480ms/step
# Epoch 989/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8659 - 2s/epoch - 487ms/step
# Epoch 990/1000
# 4/4 - 2s - loss: 0.0174 - accuracy: 0.8845 - 2s/epoch - 489ms/step
# Epoch 991/1000
# 4/4 - 2s - loss: 0.0177 - accuracy: 0.8766 - 2s/epoch - 512ms/step
# Epoch 992/1000
# 4/4 - 2s - loss: 0.0169 - accuracy: 0.8824 - 2s/epoch - 488ms/step
# Epoch 993/1000
# 4/4 - 2s - loss: 0.0169 - accuracy: 0.8857 - 2s/epoch - 500ms/step
# Epoch 994/1000
# 4/4 - 2s - loss: 0.0170 - accuracy: 0.8787 - 2s/epoch - 494ms/step
# Epoch 995/1000
# 4/4 - 2s - loss: 0.0175 - accuracy: 0.8836 - 2s/epoch - 486ms/step
# Epoch 996/1000
# 4/4 - 2s - loss: 0.0176 - accuracy: 0.8683 - 2s/epoch - 493ms/step
# Epoch 997/1000
# 4/4 - 2s - loss: 0.0173 - accuracy: 0.8768 - 2s/epoch - 497ms/step
# Epoch 998/1000
# 4/4 - 2s - loss: 0.0179 - accuracy: 0.8812 - 2s/epoch - 487ms/step
# Epoch 999/1000
# 4/4 - 2s - loss: 0.0169 - accuracy: 0.8737 - 2s/epoch - 486ms/step
# Epoch 1000/1000
# 4/4 - 2s - loss: 0.0169 - accuracy: 0.8850 - 2s/epoch - 496ms/step
# Wall time: 35min 52s

# %% [markdown]
# # PREDICTION

# %%
#filename = 'New256_E1000_mae.h'
#model.save(filename)
model = load_model(r"C:\Users\danie\Documents\GitHub\MachineLearningClass\Azure2")

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
def get_photo(image):
    prep_color, prep_bw = prep_img(image_path)
    test_predict = model.predict(prep_bw)
    #print(test_predict)
    print('test_range_A:', np.min(test_predict[:,:,0]), np.max(test_predict[:,:,0]))
    print('test_range_B:', np.min(test_predict[:,:,1]), np.max(test_predict[:,:,1]))
    
    test_predict_reshaped= test_predict[0,:,:,:]
    #test_predict_reshaped = test_predict_reshaped*128
    test_predict_reshaped = (test_predict_reshaped*256)-128
    #print(test_predict_reshaped)
    BW_reshaped  = prep_bw[0,:,:,:]
    
    print('test_reshaped_A:', np.min(test_predict_reshaped[:,:,0]), np.max(test_predict_reshaped[:,:,0]))
    print(len(np.unique(test_predict_reshaped[:,:,0]))) #, return_counts=True
    print('test_reshaped_B:', np.min(test_predict_reshaped[:,:,1]), np.max(test_predict_reshaped[:,:,1]))
    test_merged_LAB = np.dstack((BW_reshaped, test_predict_reshaped))
    test_merged_rgb = color.lab2rgb(test_merged_LAB)
    
    plt.figure(figsize=(10, 10))
    plt.imshow(test_merged_rgb)

# %%
image_path = r"C:\Users\danie\Desktop\new pre\7.jpg"

# %%
PCA_YN = "no"
get_photo(image_path)
# Out:
# Padded: 0.0 255.0
# PCA did not run
# 256
# 256
# (256, 256, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 1.7360022039118306 100.0
# Y_LAB_org: -44.104645421275855 50.01033622849511
# Y_LAB: 0.3277162288231412 0.695352875892559
# (256, 256)
# image processed
# test_range_A: 0.47032666 0.522479
# test_range_B: 0.47032666 0.522479
# test_reshaped_A: -10.888832 -1.2053833
# 55
# test_reshaped_B: 1.2323456 5.985016
