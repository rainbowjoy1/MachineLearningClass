# %%
#single_image = r"C:\Users\danie\Desktop\tiny rainbow.jpg"
image_folder = r"C:\Users\midyr\Downloads\colorwheels"
image_pathway = r"C:\Users\midyr\Downloads\colorwheels\colorwheel.png"

TOO_SMALL = 20
SMALL = 500000
MEDIUM = 1200000
LARGE = 2100000
    
X_train = []
Y_train = []
counter = 1
    
height = 128
width = 128

#epochs = 10 
#batch_size = 1 
total_images = 1

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import skimage
import glob
import cv2
import pandas as pd
from tensorflow.keras import callbacks
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, UpSampling2D, InputLayer, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from skimage import data, io, color
from skimage.io import imread, imshow, imsave
from pathlib import Path

from sklearn.decomposition import PCA

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
def shape(img):
    size = 0
    resolution = img.shape[0] * img.shape[1]
    if resolution <= TOO_SMALL:
        size = 0
    elif resolution <= SMALL:
        size = 1
    elif resolution <= MEDIUM:
        size = 2
    elif resolution <= LARGE:
        size = 3
    else:
        size = 6
    return size

# %%
def create_dataframe(image_folder):
    images = Path(image_folder).glob('*.png') #.png

    list_of_files = []
    for image in images:
        list_of_files.append(str(image))

    df = pd. DataFrame(list_of_files, columns = ["image_path"])
    df_length = len(df.index)
    
    print("processing", df_length, "photos for training")
    
    height_list= []
    width_list = []
    resolution = []
    
    for image_path in df['image_path']:
        img = cv2.imread(str(image_path))
        height_list.append(img.shape[0])
        width_list.append(img.shape[1])
        
    df["height"] = height_list
    df["width"] = width_list
    df["resolution"] = df["height"] * df["width"]
    
    df = df[df.resolution < LARGE]
    
    ll = df_length - len(df.index)
    print("dropped ", ll, "photos because they were too large to process")
    
    df = df[df.resolution > TOO_SMALL]
    
    ss = df_length - len(df.index) - ll
    print("dropped ", ss, "photos because they were too small to process")
    df.head()
    
    return df

# %%
def pca_rgb(imgBGR, size): #imgRGB, size
    b,g,r = cv2.split(imgBGR)
    list_channels = [b,g,r]
    
    #check size first
    if size ==1:
        inverted_img = []
        for c in list_channels:            
            pca = PCA(n_components = 100)
            transformed = pca.fit_transform(c/255) #r_scaled
            inverted = pca.inverse_transform(transformed)
            inverted_img.append(inverted)
        
        tuple(inverted_img)
        RGB_compressed = cv2.merge(inverted_img)    

    elif size == 2:
        inverted_img = []
        for c in list_channels:            
            pca = PCA(n_components = 300)
            transformed = pca.fit_transform(c/255) #r_scaled
            inverted = pca.inverse_transform(transformed)
            inverted_img.append(inverted)
        
        tuple(inverted_img)
        RGB_compressed = cv2.merge(inverted_img)
    else:
        inverted_img = []
        for c in list_channels:            
            pca = PCA(n_components = 500)
            transformed = pca.fit_transform(c/255) #r_scaled
            inverted = pca.inverse_transform(transformed)
            inverted_img.append(inverted)
        
        tuple(inverted_img)
        RGB_compressed = cv2.merge(inverted_img)
        
    RGB_compressed = np.float32(RGB_compressed)
    print("PCA SHAPE",np.min(RGB_compressed),np.max(RGB_compressed))    
    return RGB_compressed

# %%
def rgb_pad(image):
    
    img_height = image.shape[0]
    print(height)
    img_width = image.shape[1]
    print(width)
    
    WHITE = [255,255,255] #[255,255,255]  1, 1, 1
    
    if img_height % 2 == 0:
        top = int((height - img_height)/ 2)
        bottom = int((height - img_height)/ 2)
    else: 
        top = int((height - (img_height-1))/ 2)
        bottom = int(((height - (img_height-1))/ 2)-1)

    if img_width % 2 == 0:
        left = int((width - img_width)/ 2)
        right = int((width - img_width)/ 2)
    else: 
        left = int((width - (img_width-1))/ 2)
        right = int(((width - (img_width-1))/2)-1)
    
    image = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT,value=WHITE)
    print(image.shape)
    print(np.min(image),np.max(image))

    return image

# %%
def prep_img(img_path):
    imgRGB = img_to_array(load_img(img_path))
    imgRGB = np.array(imgRGB, dtype=float)
    print('Padded:', np.min(imgRGB), np.max(imgRGB))



    image_size_category = shape(imgRGB) 
    if image_size_category <1:
        raise Exception("Your image is too small to be used")
    elif image_size_category >4:
        raise Exception("Your image is too big to be used")

    if PCA_YN == "yes":
        RGB_compressed = pca_rgb(imgRGB, image_size_category)
        RGB_compressed = np.clip(RGB_compressed,0,1) * 255
        print("PCA ran")
    else:
        RGB_compressed = imgRGB
        print("PCA did not run")


    
    padded_image = rgb_pad(RGB_compressed)

    print('Padded:', np.min(padded_image), np.max(padded_image))
    X_LAB = color.rgb2lab(1.0/255*padded_image)[:,:,0] #1.0/255*padded_image
    print('X_LAB:', np.min(X_LAB), np.max(X_LAB))
    Y_LAB1 = color.rgb2lab(1.0/255*padded_image)[:,:,1:] #1.0/255*padded_image
    print('Y_LAB_org:', np.min(Y_LAB1), np.max(Y_LAB1))
    #Y_LAB = Y_LAB1 / 128
    Y_LAB = (Y_LAB1 + 128)/ 256
    print('Y_LAB:', np.min(Y_LAB), np.max(Y_LAB))


    print(X_LAB.shape)
    X = X_LAB.reshape(1, height, width, 1) #comment out when show predicted
    Y = Y_LAB.reshape(1, height, width, 2) #comment out when show predicted
    
    print("image processed")

    return Y, X

# %%
def prep_dataframe(df):
    for index, row in df.iterrows():
        Y, X = prep_img(row["image_path"])
        Y_train.append(Y)
        X_train.append(X)

# %%
PCA_YN = "no"

#prep_image(single_image)

df = create_dataframe(image_folder)
prep_dataframe(df)
# Out:
# processing 2 photos for training
# dropped  0 photos because they were too large to process
# dropped  0 photos because they were too small to process
# Padded: 0.0 255.0
# PCA did not run
# 128
# 128
# (128, 128, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 21.73390280398273 100.0
# Y_LAB_org: -82.93441399808646 93.91007169334684
# Y_LAB: 0.17603744531997478 0.866836217552136
# (128, 128)
# image processed
# Padded: 0.0 255.0
# PCA did not run
# 128
# 128
# (128, 128, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 21.73390280398273 100.0
# Y_LAB_org: -82.93441399808646 93.91007169334684
# Y_LAB: 0.17603744531997478 0.866836217552136
# (128, 128)
# image processed

# %% [markdown]
# # MODEL

# %%
BATCH_SIZE = 1
LEARNING_RATE = 0.001
EPOCHS = 500 #100
KERNEL_SIZE = 2 
NUM_CLASSES = 2 #313
IMAGE_WIDTH = 128 #128
IMAGE_HEIGHT = 128 #128
#SIGMA = 5

#early_stopping_cb = callbacks.EarlyStopping(patience = 5, restore_best_weights = True)

# %%
def mode():
   
    model = tf.keras.Sequential([
    Conv2D(32, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(32, kernel_size=KERNEL_SIZE, activation='relu', padding='same', strides=(2, 2)),
    BatchNormalization(),

    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same', strides=(2, 2)),
    BatchNormalization(),

    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same', strides=(2, 2)),
    BatchNormalization(),

    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    BatchNormalization(),

    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    BatchNormalization(),

    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    Conv2D(256, kernel_size=KERNEL_SIZE, activation='relu', padding='same', dilation_rate=2),
    BatchNormalization(),

    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(128, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    BatchNormalization(),

    UpSampling2D(size=(2, 2)),
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    Conv2D(64, kernel_size=KERNEL_SIZE, activation='relu', padding='same'),
    BatchNormalization(),

    Conv2D(NUM_CLASSES, kernel_size=1, padding='same', activation='softmax'), UpSampling2D(size=(4, 4))
        ])
    
    model.compile(optimizer ="adam", loss = "CategoricalCrossentropy", metrics = ["accuracy"])
    
    return model 

#?? Acitivation function and Loss function

# %%
model = mode()

# %%
model.build((1,128,128,1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (1, 128, 128, 32)         160
#
#  conv2d_1 (Conv2D)           (1, 64, 64, 32)           4128
#
#  batch_normalization (BatchN  (1, 64, 64, 32)          128
#  ormalization)
#
#  conv2d_2 (Conv2D)           (1, 64, 64, 64)           8256
#
#  conv2d_3 (Conv2D)           (1, 32, 32, 64)           16448
#
#  batch_normalization_1 (Batc  (1, 32, 32, 64)          256
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (1, 32, 32, 128)          32896
#
#  conv2d_5 (Conv2D)           (1, 32, 32, 128)          65664
#
#  conv2d_6 (Conv2D)           (1, 16, 16, 128)          65664
#
#  batch_normalization_2 (Batc  (1, 16, 16, 128)         512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (1, 16, 16, 256)          131328
#
#  conv2d_8 (Conv2D)           (1, 16, 16, 256)          262400
#
#  conv2d_9 (Conv2D)           (1, 16, 16, 256)          262400
#
#  batch_normalization_3 (Batc  (1, 16, 16, 256)         1024
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (1, 16, 16, 256)          262400
#
#  conv2d_11 (Conv2D)          (1, 16, 16, 256)          262400
#
#  conv2d_12 (Conv2D)          (1, 16, 16, 256)          262400
#
#  batch_normalization_4 (Batc  (1, 16, 16, 256)         1024
#  hNormalization)
#
#  conv2d_13 (Conv2D)          (1, 16, 16, 256)          262400
#
#  conv2d_14 (Conv2D)          (1, 16, 16, 256)          262400
#
#  conv2d_15 (Conv2D)          (1, 16, 16, 256)          262400
#
#  batch_normalization_5 (Batc  (1, 16, 16, 256)         1024
#  hNormalization)
#
#  conv2d_16 (Conv2D)          (1, 16, 16, 128)          131200
#
#  conv2d_17 (Conv2D)          (1, 16, 16, 128)          65664
#
#  conv2d_18 (Conv2D)          (1, 16, 16, 128)          65664
#
#  batch_normalization_6 (Batc  (1, 16, 16, 128)         512
#  hNormalization)
#
#  up_sampling2d (UpSampling2D  (1, 32, 32, 128)         0
#  )
#
#  conv2d_19 (Conv2D)          (1, 32, 32, 64)           32832
#
#  conv2d_20 (Conv2D)          (1, 32, 32, 64)           16448
#
#  conv2d_21 (Conv2D)          (1, 32, 32, 64)           16448
#
#  batch_normalization_7 (Batc  (1, 32, 32, 64)          256
#  hNormalization)
#
#  conv2d_22 (Conv2D)          (1, 32, 32, 2)            130
#
#  up_sampling2d_1 (UpSampling  (1, 128, 128, 2)         0
#  2D)
#
# =================================================================
# Total params: 2,756,866
# Trainable params: 2,754,498
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
train_data = tf.data.Dataset.from_tensor_slices((X_train, Y_train))

# %%
len(X_train)
# Out:
# 2

# %%
# %%time
history = model.fit(train_data, batch_size = BATCH_SIZE, epochs = EPOCHS, verbose = 2)  # add validation_split = 0.2
# Out:
# Epoch 1/500
# 2/2 - 1s - loss: 1.0872 - accuracy: 0.5028 - 1s/epoch - 552ms/step
# Epoch 2/500
# 2/2 - 0s - loss: 0.9093 - accuracy: 0.5765 - 99ms/epoch - 49ms/step
# Epoch 3/500
# 2/2 - 0s - loss: 0.8159 - accuracy: 0.5756 - 107ms/epoch - 53ms/step
# Epoch 4/500
# 2/2 - 0s - loss: 0.7628 - accuracy: 0.6604 - 101ms/epoch - 51ms/step
# Epoch 5/500
# 2/2 - 0s - loss: 0.7387 - accuracy: 0.6764 - 105ms/epoch - 52ms/step
# Epoch 6/500
# 2/2 - 0s - loss: 0.7295 - accuracy: 0.7100 - 102ms/epoch - 51ms/step
# Epoch 7/500
# 2/2 - 0s - loss: 0.7259 - accuracy: 0.7231 - 104ms/epoch - 52ms/step
# Epoch 8/500
# 2/2 - 0s - loss: 0.7237 - accuracy: 0.7080 - 100ms/epoch - 50ms/step
# Epoch 9/500
# 2/2 - 0s - loss: 0.7221 - accuracy: 0.6951 - 104ms/epoch - 52ms/step
# Epoch 10/500
# 2/2 - 0s - loss: 0.7212 - accuracy: 0.6776 - 107ms/epoch - 53ms/step
# Epoch 11/500
# 2/2 - 0s - loss: 0.7205 - accuracy: 0.6701 - 103ms/epoch - 51ms/step
# Epoch 12/500
# 2/2 - 0s - loss: 0.7201 - accuracy: 0.6865 - 103ms/epoch - 52ms/step
# Epoch 13/500
# 2/2 - 0s - loss: 0.7198 - accuracy: 0.6903 - 103ms/epoch - 51ms/step
# Epoch 14/500
# 2/2 - 0s - loss: 0.7195 - accuracy: 0.6935 - 99ms/epoch - 50ms/step
# Epoch 15/500
# 2/2 - 0s - loss: 0.7192 - accuracy: 0.7033 - 107ms/epoch - 54ms/step
# Epoch 16/500
# 2/2 - 0s - loss: 0.7190 - accuracy: 0.7386 - 102ms/epoch - 51ms/step
# Epoch 17/500
# 2/2 - 0s - loss: 0.7189 - accuracy: 0.7500 - 106ms/epoch - 53ms/step
# Epoch 18/500
# 2/2 - 0s - loss: 0.7188 - accuracy: 0.7640 - 103ms/epoch - 51ms/step
# Epoch 19/500
# 2/2 - 0s - loss: 0.7187 - accuracy: 0.7827 - 102ms/epoch - 51ms/step
# Epoch 20/500
# 2/2 - 0s - loss: 0.7187 - accuracy: 0.7667 - 100ms/epoch - 50ms/step
# Epoch 21/500
# 2/2 - 0s - loss: 0.7186 - accuracy: 0.7488 - 104ms/epoch - 52ms/step
# Epoch 22/500
# 2/2 - 0s - loss: 0.7186 - accuracy: 0.7194 - 105ms/epoch - 52ms/step
# Epoch 23/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7202 - 103ms/epoch - 51ms/step
# Epoch 24/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7062 - 104ms/epoch - 52ms/step
# Epoch 25/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.6908 - 104ms/epoch - 52ms/step
# Epoch 26/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.6947 - 108ms/epoch - 54ms/step
# Epoch 27/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7021 - 109ms/epoch - 54ms/step
# Epoch 28/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7234 - 103ms/epoch - 52ms/step
# Epoch 29/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7377 - 102ms/epoch - 51ms/step
# Epoch 30/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7646 - 104ms/epoch - 52ms/step
# Epoch 31/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7649 - 103ms/epoch - 52ms/step
# Epoch 32/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7740 - 104ms/epoch - 52ms/step
# Epoch 33/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7664 - 104ms/epoch - 52ms/step
# Epoch 34/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7523 - 103ms/epoch - 52ms/step
# Epoch 35/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7332 - 103ms/epoch - 51ms/step
# Epoch 36/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7180 - 101ms/epoch - 51ms/step
# Epoch 37/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7145 - 103ms/epoch - 51ms/step
# Epoch 38/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7283 - 100ms/epoch - 50ms/step
# Epoch 39/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7295 - 103ms/epoch - 51ms/step
# Epoch 40/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7389 - 103ms/epoch - 52ms/step
# Epoch 41/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7542 - 103ms/epoch - 51ms/step
# Epoch 42/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7667 - 102ms/epoch - 51ms/step
# Epoch 43/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7688 - 98ms/epoch - 49ms/step
# Epoch 44/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7642 - 98ms/epoch - 49ms/step
# Epoch 45/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7554 - 100ms/epoch - 50ms/step
# Epoch 46/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7543 - 102ms/epoch - 51ms/step
# Epoch 47/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7430 - 105ms/epoch - 52ms/step
# Epoch 48/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7358 - 102ms/epoch - 51ms/step
# Epoch 49/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7307 - 103ms/epoch - 52ms/step
# Epoch 50/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7376 - 103ms/epoch - 51ms/step
# Epoch 51/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7465 - 109ms/epoch - 55ms/step
# Epoch 52/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7581 - 108ms/epoch - 54ms/step
# Epoch 53/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7639 - 104ms/epoch - 52ms/step
# Epoch 54/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7632 - 102ms/epoch - 51ms/step
# Epoch 55/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7583 - 107ms/epoch - 54ms/step
# Epoch 56/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7544 - 109ms/epoch - 54ms/step
# Epoch 57/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7499 - 101ms/epoch - 50ms/step
# Epoch 58/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7462 - 101ms/epoch - 51ms/step
# Epoch 59/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7485 - 105ms/epoch - 53ms/step
# Epoch 60/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7524 - 101ms/epoch - 50ms/step
# Epoch 61/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7562 - 101ms/epoch - 51ms/step
# Epoch 62/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7612 - 99ms/epoch - 49ms/step
# Epoch 63/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7713 - 99ms/epoch - 50ms/step
# Epoch 64/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7795 - 101ms/epoch - 51ms/step
# Epoch 65/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7727 - 104ms/epoch - 52ms/step
# Epoch 66/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7634 - 103ms/epoch - 52ms/step
# Epoch 67/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7541 - 104ms/epoch - 52ms/step
# Epoch 68/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7507 - 100ms/epoch - 50ms/step
# Epoch 69/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7535 - 118ms/epoch - 59ms/step
# Epoch 70/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7629 - 127ms/epoch - 63ms/step
# Epoch 71/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7676 - 104ms/epoch - 52ms/step
# Epoch 72/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7629 - 100ms/epoch - 50ms/step
# Epoch 73/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7654 - 108ms/epoch - 54ms/step
# Epoch 74/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7717 - 109ms/epoch - 54ms/step
# Epoch 75/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7726 - 107ms/epoch - 54ms/step
# Epoch 76/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7686 - 103ms/epoch - 52ms/step
# Epoch 77/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7615 - 104ms/epoch - 52ms/step
# Epoch 78/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7643 - 102ms/epoch - 51ms/step
# Epoch 79/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7623 - 102ms/epoch - 51ms/step
# Epoch 80/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7696 - 102ms/epoch - 51ms/step
# Epoch 81/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7724 - 107ms/epoch - 54ms/step
# Epoch 82/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7694 - 105ms/epoch - 53ms/step
# Epoch 83/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7733 - 103ms/epoch - 52ms/step
# Epoch 84/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7708 - 107ms/epoch - 53ms/step
# Epoch 85/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7734 - 106ms/epoch - 53ms/step
# Epoch 86/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7694 - 103ms/epoch - 51ms/step
# Epoch 87/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7699 - 106ms/epoch - 53ms/step
# Epoch 88/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7655 - 107ms/epoch - 53ms/step
# Epoch 89/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7719 - 108ms/epoch - 54ms/step
# Epoch 90/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7704 - 107ms/epoch - 53ms/step
# Epoch 91/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7759 - 107ms/epoch - 53ms/step
# Epoch 92/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7778 - 105ms/epoch - 53ms/step
# Epoch 93/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7758 - 104ms/epoch - 52ms/step
# Epoch 94/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7701 - 101ms/epoch - 50ms/step
# Epoch 95/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7745 - 100ms/epoch - 50ms/step
# Epoch 96/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7784 - 101ms/epoch - 50ms/step
# Epoch 97/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7765 - 99ms/epoch - 50ms/step
# Epoch 98/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7740 - 101ms/epoch - 51ms/step
# Epoch 99/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7804 - 99ms/epoch - 49ms/step
# Epoch 100/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7814 - 102ms/epoch - 51ms/step
# Epoch 101/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7760 - 99ms/epoch - 49ms/step
# Epoch 102/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7823 - 101ms/epoch - 50ms/step
# Epoch 103/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7838 - 99ms/epoch - 49ms/step
# Epoch 104/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7780 - 98ms/epoch - 49ms/step
# Epoch 105/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7882 - 99ms/epoch - 50ms/step
# Epoch 106/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7867 - 99ms/epoch - 50ms/step
# Epoch 107/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7828 - 97ms/epoch - 49ms/step
# Epoch 108/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7843 - 99ms/epoch - 49ms/step
# Epoch 109/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7869 - 99ms/epoch - 49ms/step
# Epoch 110/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7882 - 99ms/epoch - 50ms/step
# Epoch 111/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7825 - 98ms/epoch - 49ms/step
# Epoch 112/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7981 - 101ms/epoch - 50ms/step
# Epoch 113/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7971 - 99ms/epoch - 49ms/step
# Epoch 114/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7825 - 100ms/epoch - 50ms/step
# Epoch 115/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7893 - 98ms/epoch - 49ms/step
# Epoch 116/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7961 - 100ms/epoch - 50ms/step
# Epoch 117/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7849 - 105ms/epoch - 52ms/step
# Epoch 118/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7938 - 104ms/epoch - 52ms/step
# Epoch 119/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7924 - 95ms/epoch - 47ms/step
# Epoch 120/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8016 - 96ms/epoch - 48ms/step
# Epoch 121/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8016 - 99ms/epoch - 49ms/step
# Epoch 122/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7938 - 98ms/epoch - 49ms/step
# Epoch 123/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7960 - 96ms/epoch - 48ms/step
# Epoch 124/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7971 - 100ms/epoch - 50ms/step
# Epoch 125/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8052 - 101ms/epoch - 50ms/step
# Epoch 126/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8065 - 97ms/epoch - 49ms/step
# Epoch 127/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7997 - 100ms/epoch - 50ms/step
# Epoch 128/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7977 - 102ms/epoch - 51ms/step
# Epoch 129/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8027 - 98ms/epoch - 49ms/step
# Epoch 130/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8042 - 97ms/epoch - 48ms/step
# Epoch 131/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7974 - 95ms/epoch - 48ms/step
# Epoch 132/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7983 - 103ms/epoch - 51ms/step
# Epoch 133/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7998 - 101ms/epoch - 51ms/step
# Epoch 134/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8003 - 99ms/epoch - 49ms/step
# Epoch 135/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7993 - 101ms/epoch - 51ms/step
# Epoch 136/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7978 - 101ms/epoch - 51ms/step
# Epoch 137/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7914 - 100ms/epoch - 50ms/step
# Epoch 138/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7905 - 99ms/epoch - 50ms/step
# Epoch 139/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7870 - 103ms/epoch - 52ms/step
# Epoch 140/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7812 - 99ms/epoch - 50ms/step
# Epoch 141/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7719 - 102ms/epoch - 51ms/step
# Epoch 142/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7674 - 108ms/epoch - 54ms/step
# Epoch 143/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7676 - 102ms/epoch - 51ms/step
# Epoch 144/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7609 - 101ms/epoch - 51ms/step
# Epoch 145/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7546 - 100ms/epoch - 50ms/step
# Epoch 146/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7484 - 98ms/epoch - 49ms/step
# Epoch 147/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7424 - 100ms/epoch - 50ms/step
# Epoch 148/500
# 2/2 - 0s - loss: 0.7186 - accuracy: 0.7379 - 97ms/epoch - 48ms/step
# Epoch 149/500
# 2/2 - 0s - loss: 0.7189 - accuracy: 0.7321 - 103ms/epoch - 51ms/step
# Epoch 150/500
# 2/2 - 0s - loss: 0.7186 - accuracy: 0.7540 - 100ms/epoch - 50ms/step
# Epoch 151/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7625 - 96ms/epoch - 48ms/step
# Epoch 152/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7350 - 100ms/epoch - 50ms/step
# Epoch 153/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7289 - 103ms/epoch - 52ms/step
# Epoch 154/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7660 - 99ms/epoch - 49ms/step
# Epoch 155/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7545 - 100ms/epoch - 50ms/step
# Epoch 156/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6415 - 103ms/epoch - 51ms/step
# Epoch 157/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7524 - 102ms/epoch - 51ms/step
# Epoch 158/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8127 - 102ms/epoch - 51ms/step
# Epoch 159/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7178 - 97ms/epoch - 49ms/step
# Epoch 160/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7476 - 102ms/epoch - 51ms/step
# Epoch 161/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8680 - 99ms/epoch - 49ms/step
# Epoch 162/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7469 - 100ms/epoch - 50ms/step
# Epoch 163/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7428 - 101ms/epoch - 50ms/step
# Epoch 164/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8531 - 98ms/epoch - 49ms/step
# Epoch 165/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7510 - 104ms/epoch - 52ms/step
# Epoch 166/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7167 - 99ms/epoch - 49ms/step
# Epoch 167/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8206 - 101ms/epoch - 51ms/step
# Epoch 168/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7588 - 98ms/epoch - 49ms/step
# Epoch 169/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6747 - 100ms/epoch - 50ms/step
# Epoch 170/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7778 - 111ms/epoch - 56ms/step
# Epoch 171/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7701 - 114ms/epoch - 57ms/step
# Epoch 172/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6822 - 114ms/epoch - 57ms/step
# Epoch 173/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7666 - 106ms/epoch - 53ms/step
# Epoch 174/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8214 - 107ms/epoch - 53ms/step
# Epoch 175/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7409 - 103ms/epoch - 51ms/step
# Epoch 176/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7547 - 103ms/epoch - 52ms/step
# Epoch 177/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8459 - 103ms/epoch - 52ms/step
# Epoch 178/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7554 - 102ms/epoch - 51ms/step
# Epoch 179/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7081 - 102ms/epoch - 51ms/step
# Epoch 180/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7930 - 103ms/epoch - 51ms/step
# Epoch 181/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7829 - 100ms/epoch - 50ms/step
# Epoch 182/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7227 - 101ms/epoch - 51ms/step
# Epoch 183/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7686 - 100ms/epoch - 50ms/step
# Epoch 184/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8270 - 100ms/epoch - 50ms/step
# Epoch 185/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7618 - 105ms/epoch - 52ms/step
# Epoch 186/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7406 - 102ms/epoch - 51ms/step
# Epoch 187/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7772 - 98ms/epoch - 49ms/step
# Epoch 188/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7849 - 101ms/epoch - 51ms/step
# Epoch 189/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7589 - 104ms/epoch - 52ms/step
# Epoch 190/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7730 - 104ms/epoch - 52ms/step
# Epoch 191/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8229 - 100ms/epoch - 50ms/step
# Epoch 192/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7811 - 100ms/epoch - 50ms/step
# Epoch 193/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7495 - 101ms/epoch - 51ms/step
# Epoch 194/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7787 - 100ms/epoch - 50ms/step
# Epoch 195/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8362 - 97ms/epoch - 49ms/step
# Epoch 196/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7775 - 101ms/epoch - 51ms/step
# Epoch 197/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7616 - 101ms/epoch - 50ms/step
# Epoch 198/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7847 - 101ms/epoch - 50ms/step
# Epoch 199/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8396 - 99ms/epoch - 50ms/step
# Epoch 200/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7859 - 98ms/epoch - 49ms/step
# Epoch 201/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7855 - 95ms/epoch - 48ms/step
# Epoch 202/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7889 - 98ms/epoch - 49ms/step
# Epoch 203/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8402 - 98ms/epoch - 49ms/step
# Epoch 204/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8026 - 98ms/epoch - 49ms/step
# Epoch 205/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8016 - 99ms/epoch - 49ms/step
# Epoch 206/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8016 - 99ms/epoch - 49ms/step
# Epoch 207/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8300 - 98ms/epoch - 49ms/step
# Epoch 208/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8221 - 99ms/epoch - 50ms/step
# Epoch 209/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8109 - 99ms/epoch - 50ms/step
# Epoch 210/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8177 - 100ms/epoch - 50ms/step
# Epoch 211/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8241 - 96ms/epoch - 48ms/step
# Epoch 212/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8383 - 97ms/epoch - 48ms/step
# Epoch 213/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8251 - 96ms/epoch - 48ms/step
# Epoch 214/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8265 - 99ms/epoch - 49ms/step
# Epoch 215/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8309 - 99ms/epoch - 49ms/step
# Epoch 216/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8436 - 99ms/epoch - 49ms/step
# Epoch 217/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8387 - 100ms/epoch - 50ms/step
# Epoch 218/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8270 - 98ms/epoch - 49ms/step
# Epoch 219/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8344 - 97ms/epoch - 49ms/step
# Epoch 220/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8319 - 97ms/epoch - 48ms/step
# Epoch 221/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8368 - 98ms/epoch - 49ms/step
# Epoch 222/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8397 - 98ms/epoch - 49ms/step
# Epoch 223/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8363 - 98ms/epoch - 49ms/step
# Epoch 224/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8363 - 97ms/epoch - 49ms/step
# Epoch 225/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8378 - 99ms/epoch - 50ms/step
# Epoch 226/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8407 - 97ms/epoch - 48ms/step
# Epoch 227/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8431 - 97ms/epoch - 49ms/step
# Epoch 228/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8417 - 97ms/epoch - 48ms/step
# Epoch 229/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8412 - 99ms/epoch - 50ms/step
# Epoch 230/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8417 - 101ms/epoch - 51ms/step
# Epoch 231/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8431 - 105ms/epoch - 52ms/step
# Epoch 232/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8417 - 104ms/epoch - 52ms/step
# Epoch 233/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8461 - 103ms/epoch - 52ms/step
# Epoch 234/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8461 - 104ms/epoch - 52ms/step
# Epoch 235/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8461 - 105ms/epoch - 52ms/step
# Epoch 236/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8436 - 102ms/epoch - 51ms/step
# Epoch 237/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8431 - 104ms/epoch - 52ms/step
# Epoch 238/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8451 - 102ms/epoch - 51ms/step
# Epoch 239/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8456 - 105ms/epoch - 52ms/step
# Epoch 240/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8461 - 100ms/epoch - 50ms/step
# Epoch 241/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8485 - 100ms/epoch - 50ms/step
# Epoch 242/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8456 - 99ms/epoch - 50ms/step
# Epoch 243/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8475 - 101ms/epoch - 51ms/step
# Epoch 244/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8461 - 99ms/epoch - 50ms/step
# Epoch 245/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8456 - 101ms/epoch - 51ms/step
# Epoch 246/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8490 - 100ms/epoch - 50ms/step
# Epoch 247/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8539 - 98ms/epoch - 49ms/step
# Epoch 248/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8510 - 100ms/epoch - 50ms/step
# Epoch 249/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8500 - 100ms/epoch - 50ms/step
# Epoch 250/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8500 - 100ms/epoch - 50ms/step
# Epoch 251/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8539 - 102ms/epoch - 51ms/step
# Epoch 252/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8549 - 104ms/epoch - 52ms/step
# Epoch 253/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8558 - 101ms/epoch - 51ms/step
# Epoch 254/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8544 - 102ms/epoch - 51ms/step
# Epoch 255/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8558 - 100ms/epoch - 50ms/step
# Epoch 256/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8573 - 103ms/epoch - 51ms/step
# Epoch 257/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8553 - 101ms/epoch - 51ms/step
# Epoch 258/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8563 - 99ms/epoch - 49ms/step
# Epoch 259/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8534 - 98ms/epoch - 49ms/step
# Epoch 260/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8563 - 99ms/epoch - 49ms/step
# Epoch 261/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8524 - 99ms/epoch - 50ms/step
# Epoch 262/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8470 - 102ms/epoch - 51ms/step
# Epoch 263/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8339 - 98ms/epoch - 49ms/step
# Epoch 264/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8090 - 99ms/epoch - 50ms/step
# Epoch 265/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7870 - 102ms/epoch - 51ms/step
# Epoch 266/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7787 - 102ms/epoch - 51ms/step
# Epoch 267/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7734 - 101ms/epoch - 50ms/step
# Epoch 268/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7662 - 101ms/epoch - 51ms/step
# Epoch 269/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7579 - 103ms/epoch - 51ms/step
# Epoch 270/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7581 - 96ms/epoch - 48ms/step
# Epoch 271/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7541 - 100ms/epoch - 50ms/step
# Epoch 272/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7472 - 98ms/epoch - 49ms/step
# Epoch 273/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7424 - 100ms/epoch - 50ms/step
# Epoch 274/500
# 2/2 - 0s - loss: 0.7187 - accuracy: 0.7361 - 99ms/epoch - 50ms/step
# Epoch 275/500
# 2/2 - 0s - loss: 0.7190 - accuracy: 0.7305 - 99ms/epoch - 50ms/step
# Epoch 276/500
# 2/2 - 0s - loss: 0.7186 - accuracy: 0.7604 - 97ms/epoch - 49ms/step
# Epoch 277/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7527 - 99ms/epoch - 49ms/step
# Epoch 278/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7350 - 100ms/epoch - 50ms/step
# Epoch 279/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7276 - 98ms/epoch - 49ms/step
# Epoch 280/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7811 - 101ms/epoch - 50ms/step
# Epoch 281/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7513 - 97ms/epoch - 49ms/step
# Epoch 282/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6539 - 97ms/epoch - 49ms/step
# Epoch 283/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7428 - 100ms/epoch - 50ms/step
# Epoch 284/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8255 - 101ms/epoch - 50ms/step
# Epoch 285/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7330 - 101ms/epoch - 51ms/step
# Epoch 286/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7422 - 99ms/epoch - 49ms/step
# Epoch 287/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8616 - 97ms/epoch - 48ms/step
# Epoch 288/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7424 - 97ms/epoch - 49ms/step
# Epoch 289/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7279 - 98ms/epoch - 49ms/step
# Epoch 290/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8320 - 99ms/epoch - 49ms/step
# Epoch 291/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7498 - 99ms/epoch - 49ms/step
# Epoch 292/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6940 - 97ms/epoch - 48ms/step
# Epoch 293/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7897 - 99ms/epoch - 49ms/step
# Epoch 294/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7583 - 99ms/epoch - 49ms/step
# Epoch 295/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6667 - 100ms/epoch - 50ms/step
# Epoch 296/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7694 - 99ms/epoch - 49ms/step
# Epoch 297/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7755 - 98ms/epoch - 49ms/step
# Epoch 298/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6815 - 98ms/epoch - 49ms/step
# Epoch 299/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7642 - 100ms/epoch - 50ms/step
# Epoch 300/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8224 - 97ms/epoch - 48ms/step
# Epoch 301/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7323 - 99ms/epoch - 50ms/step
# Epoch 302/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7614 - 97ms/epoch - 49ms/step
# Epoch 303/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8377 - 101ms/epoch - 51ms/step
# Epoch 304/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7560 - 102ms/epoch - 51ms/step
# Epoch 305/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7444 - 99ms/epoch - 50ms/step
# Epoch 306/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8228 - 100ms/epoch - 50ms/step
# Epoch 307/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7748 - 98ms/epoch - 49ms/step
# Epoch 308/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7097 - 99ms/epoch - 49ms/step
# Epoch 309/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7876 - 101ms/epoch - 51ms/step
# Epoch 310/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7860 - 99ms/epoch - 49ms/step
# Epoch 311/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7291 - 98ms/epoch - 49ms/step
# Epoch 312/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7676 - 100ms/epoch - 50ms/step
# Epoch 313/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8445 - 97ms/epoch - 49ms/step
# Epoch 314/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7710 - 98ms/epoch - 49ms/step
# Epoch 315/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7582 - 99ms/epoch - 50ms/step
# Epoch 316/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8188 - 100ms/epoch - 50ms/step
# Epoch 317/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7829 - 101ms/epoch - 50ms/step
# Epoch 318/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7255 - 100ms/epoch - 50ms/step
# Epoch 319/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7822 - 98ms/epoch - 49ms/step
# Epoch 320/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8383 - 101ms/epoch - 51ms/step
# Epoch 321/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7740 - 100ms/epoch - 50ms/step
# Epoch 322/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7745 - 101ms/epoch - 51ms/step
# Epoch 323/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8217 - 100ms/epoch - 50ms/step
# Epoch 324/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7967 - 96ms/epoch - 48ms/step
# Epoch 325/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7670 - 97ms/epoch - 49ms/step
# Epoch 326/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7921 - 99ms/epoch - 49ms/step
# Epoch 327/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8462 - 100ms/epoch - 50ms/step
# Epoch 328/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7912 - 98ms/epoch - 49ms/step
# Epoch 329/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7976 - 96ms/epoch - 48ms/step
# Epoch 330/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8161 - 97ms/epoch - 49ms/step
# Epoch 331/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8410 - 102ms/epoch - 51ms/step
# Epoch 332/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8093 - 99ms/epoch - 50ms/step
# Epoch 333/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8161 - 100ms/epoch - 50ms/step
# Epoch 334/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8430 - 100ms/epoch - 50ms/step
# Epoch 335/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8386 - 99ms/epoch - 49ms/step
# Epoch 336/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8284 - 97ms/epoch - 49ms/step
# Epoch 337/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8259 - 98ms/epoch - 49ms/step
# Epoch 338/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8591 - 100ms/epoch - 50ms/step
# Epoch 339/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8469 - 100ms/epoch - 50ms/step
# Epoch 340/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8474 - 102ms/epoch - 51ms/step
# Epoch 341/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8474 - 97ms/epoch - 49ms/step
# Epoch 342/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8611 - 95ms/epoch - 48ms/step
# Epoch 343/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8586 - 97ms/epoch - 48ms/step
# Epoch 344/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8528 - 98ms/epoch - 49ms/step
# Epoch 345/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8538 - 99ms/epoch - 49ms/step
# Epoch 346/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8645 - 100ms/epoch - 50ms/step
# Epoch 347/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8640 - 102ms/epoch - 51ms/step
# Epoch 348/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8601 - 102ms/epoch - 51ms/step
# Epoch 349/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8621 - 103ms/epoch - 51ms/step
# Epoch 350/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8669 - 101ms/epoch - 50ms/step
# Epoch 351/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8684 - 102ms/epoch - 51ms/step
# Epoch 352/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8665 - 100ms/epoch - 50ms/step
# Epoch 353/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8684 - 102ms/epoch - 51ms/step
# Epoch 354/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8689 - 101ms/epoch - 50ms/step
# Epoch 355/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8718 - 101ms/epoch - 51ms/step
# Epoch 356/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8708 - 100ms/epoch - 50ms/step
# Epoch 357/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8728 - 99ms/epoch - 50ms/step
# Epoch 358/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8713 - 102ms/epoch - 51ms/step
# Epoch 359/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8708 - 100ms/epoch - 50ms/step
# Epoch 360/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8723 - 99ms/epoch - 49ms/step
# Epoch 361/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8699 - 100ms/epoch - 50ms/step
# Epoch 362/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8708 - 100ms/epoch - 50ms/step
# Epoch 363/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8713 - 101ms/epoch - 51ms/step
# Epoch 364/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8708 - 100ms/epoch - 50ms/step
# Epoch 365/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8704 - 101ms/epoch - 51ms/step
# Epoch 366/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8699 - 100ms/epoch - 50ms/step
# Epoch 367/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8718 - 101ms/epoch - 50ms/step
# Epoch 368/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8728 - 99ms/epoch - 49ms/step
# Epoch 369/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8718 - 99ms/epoch - 50ms/step
# Epoch 370/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8733 - 96ms/epoch - 48ms/step
# Epoch 371/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8718 - 99ms/epoch - 50ms/step
# Epoch 372/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8743 - 99ms/epoch - 49ms/step
# Epoch 373/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8752 - 101ms/epoch - 51ms/step
# Epoch 374/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8748 - 100ms/epoch - 50ms/step
# Epoch 375/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8748 - 101ms/epoch - 51ms/step
# Epoch 376/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8757 - 103ms/epoch - 52ms/step
# Epoch 377/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8767 - 102ms/epoch - 51ms/step
# Epoch 378/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8757 - 99ms/epoch - 50ms/step
# Epoch 379/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8748 - 106ms/epoch - 53ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8772 - 107ms/epoch - 53ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8806 - 104ms/epoch - 52ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8811 - 107ms/epoch - 54ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8792 - 106ms/epoch - 53ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8782 - 111ms/epoch - 55ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8796 - 107ms/epoch - 54ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8811 - 107ms/epoch - 53ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8816 - 107ms/epoch - 53ms/step
# Epoch 388/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8816 - 107ms/epoch - 53ms/step
# Epoch 389/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8806 - 102ms/epoch - 51ms/step
# Epoch 390/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8792 - 102ms/epoch - 51ms/step
# Epoch 391/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8821 - 102ms/epoch - 51ms/step
# Epoch 392/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8806 - 103ms/epoch - 51ms/step
# Epoch 393/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8821 - 100ms/epoch - 50ms/step
# Epoch 394/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8831 - 103ms/epoch - 52ms/step
# Epoch 395/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8821 - 105ms/epoch - 53ms/step
# Epoch 396/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8831 - 105ms/epoch - 52ms/step
# Epoch 397/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8840 - 102ms/epoch - 51ms/step
# Epoch 398/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8855 - 100ms/epoch - 50ms/step
# Epoch 399/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8845 - 103ms/epoch - 52ms/step
# Epoch 400/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8860 - 101ms/epoch - 50ms/step
# Epoch 401/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8860 - 101ms/epoch - 50ms/step
# Epoch 402/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8860 - 98ms/epoch - 49ms/step
# Epoch 403/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8865 - 102ms/epoch - 51ms/step
# Epoch 404/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8884 - 102ms/epoch - 51ms/step
# Epoch 405/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8889 - 102ms/epoch - 51ms/step
# Epoch 406/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8889 - 99ms/epoch - 49ms/step
# Epoch 407/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8884 - 99ms/epoch - 50ms/step
# Epoch 408/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8879 - 104ms/epoch - 52ms/step
# Epoch 409/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8865 - 102ms/epoch - 51ms/step
# Epoch 410/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8875 - 100ms/epoch - 50ms/step
# Epoch 411/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8884 - 103ms/epoch - 51ms/step
# Epoch 412/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8889 - 101ms/epoch - 50ms/step
# Epoch 413/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8875 - 101ms/epoch - 51ms/step
# Epoch 414/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8884 - 103ms/epoch - 52ms/step
# Epoch 415/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8904 - 102ms/epoch - 51ms/step
# Epoch 416/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8904 - 102ms/epoch - 51ms/step
# Epoch 417/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8889 - 101ms/epoch - 50ms/step
# Epoch 418/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8909 - 102ms/epoch - 51ms/step
# Epoch 419/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8894 - 104ms/epoch - 52ms/step
# Epoch 420/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8904 - 102ms/epoch - 51ms/step
# Epoch 421/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8909 - 105ms/epoch - 53ms/step
# Epoch 422/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8894 - 103ms/epoch - 52ms/step
# Epoch 423/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8894 - 104ms/epoch - 52ms/step
# Epoch 424/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8914 - 98ms/epoch - 49ms/step
# Epoch 425/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8914 - 104ms/epoch - 52ms/step
# Epoch 426/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8909 - 102ms/epoch - 51ms/step
# Epoch 427/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8909 - 101ms/epoch - 51ms/step
# Epoch 428/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8909 - 103ms/epoch - 52ms/step
# Epoch 429/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8918 - 102ms/epoch - 51ms/step
# Epoch 430/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8909 - 102ms/epoch - 51ms/step
# Epoch 431/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8923 - 103ms/epoch - 52ms/step
# Epoch 432/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8928 - 101ms/epoch - 50ms/step
# Epoch 433/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8914 - 101ms/epoch - 50ms/step
# Epoch 434/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8923 - 100ms/epoch - 50ms/step
# Epoch 435/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8928 - 103ms/epoch - 52ms/step
# Epoch 436/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8923 - 103ms/epoch - 51ms/step
# Epoch 437/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8904 - 98ms/epoch - 49ms/step
# Epoch 438/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8782 - 105ms/epoch - 53ms/step
# Epoch 439/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8625 - 101ms/epoch - 50ms/step
# Epoch 440/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8269 - 104ms/epoch - 52ms/step
# Epoch 441/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8054 - 99ms/epoch - 50ms/step
# Epoch 442/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7907 - 104ms/epoch - 52ms/step
# Epoch 443/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7812 - 103ms/epoch - 52ms/step
# Epoch 444/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7729 - 103ms/epoch - 52ms/step
# Epoch 445/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7650 - 101ms/epoch - 51ms/step
# Epoch 446/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7610 - 102ms/epoch - 51ms/step
# Epoch 447/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7554 - 101ms/epoch - 51ms/step
# Epoch 448/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7487 - 104ms/epoch - 52ms/step
# Epoch 449/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7443 - 107ms/epoch - 53ms/step
# Epoch 450/500
# 2/2 - 0s - loss: 0.7186 - accuracy: 0.7358 - 108ms/epoch - 54ms/step
# Epoch 451/500
# 2/2 - 0s - loss: 0.7191 - accuracy: 0.7274 - 107ms/epoch - 53ms/step
# Epoch 452/500
# 2/2 - 0s - loss: 0.7196 - accuracy: 0.7241 - 101ms/epoch - 51ms/step
# Epoch 453/500
# 2/2 - 0s - loss: 0.7186 - accuracy: 0.8053 - 102ms/epoch - 51ms/step
# Epoch 454/500
# 2/2 - 0s - loss: 0.7188 - accuracy: 0.7324 - 111ms/epoch - 56ms/step
# Epoch 455/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.6438 - 138ms/epoch - 69ms/step
# Epoch 456/500
# 2/2 - 0s - loss: 0.7186 - accuracy: 0.7497 - 107ms/epoch - 53ms/step
# Epoch 457/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7872 - 104ms/epoch - 52ms/step
# Epoch 458/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6528 - 107ms/epoch - 53ms/step
# Epoch 459/500
# 2/2 - 0s - loss: 0.7185 - accuracy: 0.7477 - 107ms/epoch - 53ms/step
# Epoch 460/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7657 - 102ms/epoch - 51ms/step
# Epoch 461/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6799 - 109ms/epoch - 55ms/step
# Epoch 462/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8358 - 109ms/epoch - 55ms/step
# Epoch 463/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7319 - 104ms/epoch - 52ms/step
# Epoch 464/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7423 - 102ms/epoch - 51ms/step
# Epoch 465/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8162 - 105ms/epoch - 52ms/step
# Epoch 466/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6597 - 100ms/epoch - 50ms/step
# Epoch 467/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7972 - 116ms/epoch - 58ms/step
# Epoch 468/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7358 - 111ms/epoch - 56ms/step
# Epoch 469/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7377 - 107ms/epoch - 54ms/step
# Epoch 470/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8281 - 107ms/epoch - 54ms/step
# Epoch 471/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6722 - 102ms/epoch - 51ms/step
# Epoch 472/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7871 - 102ms/epoch - 51ms/step
# Epoch 473/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7733 - 103ms/epoch - 52ms/step
# Epoch 474/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7390 - 103ms/epoch - 52ms/step
# Epoch 475/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8297 - 106ms/epoch - 53ms/step
# Epoch 476/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6793 - 101ms/epoch - 50ms/step
# Epoch 477/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7896 - 101ms/epoch - 51ms/step
# Epoch 478/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7573 - 101ms/epoch - 50ms/step
# Epoch 479/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7336 - 104ms/epoch - 52ms/step
# Epoch 480/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8521 - 100ms/epoch - 50ms/step
# Epoch 481/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.6929 - 104ms/epoch - 52ms/step
# Epoch 482/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7742 - 100ms/epoch - 50ms/step
# Epoch 483/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7743 - 100ms/epoch - 50ms/step
# Epoch 484/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7445 - 104ms/epoch - 52ms/step
# Epoch 485/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8468 - 107ms/epoch - 54ms/step
# Epoch 486/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7314 - 103ms/epoch - 52ms/step
# Epoch 487/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7610 - 105ms/epoch - 53ms/step
# Epoch 488/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7867 - 105ms/epoch - 53ms/step
# Epoch 489/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7197 - 102ms/epoch - 51ms/step
# Epoch 490/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8416 - 101ms/epoch - 51ms/step
# Epoch 491/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7546 - 106ms/epoch - 53ms/step
# Epoch 492/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7709 - 106ms/epoch - 53ms/step
# Epoch 493/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7996 - 104ms/epoch - 52ms/step
# Epoch 494/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7147 - 105ms/epoch - 52ms/step
# Epoch 495/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8216 - 106ms/epoch - 53ms/step
# Epoch 496/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7750 - 103ms/epoch - 51ms/step
# Epoch 497/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7708 - 101ms/epoch - 51ms/step
# Epoch 498/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.8324 - 104ms/epoch - 52ms/step
# Epoch 499/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7474 - 104ms/epoch - 52ms/step
# Epoch 500/500
# 2/2 - 0s - loss: 0.7184 - accuracy: 0.7943 - 103ms/epoch - 52ms/step
# Wall time: 55.7 s

# %%
#filename = 'Singular_Model'
#model2.save(filename)
#saved_model = load_model("Singular Model")

# %% [markdown]
# # PREDICTION

# %%
def get_photo(image):
    prep_color, prep_bw = prep_img(image_pathway)
    test_predict = model.predict(prep_bw)
    #print(test_predict)
    print('test_range:', np.min(test_predict[:,:,1]), np.max(test_predict[:,:,1]))
    
    test_predict_reshaped= test_predict[0,:,:,:]
    #test_predict_reshaped = test_predict_reshaped*128
    test_predict_reshaped = (test_predict_reshaped*256)-128
    BW_reshaped  = prep_bw[0,:,:,:]
    
    print('test_reshaped_A:', np.min(test_predict_reshaped[:,:,0]), np.max(test_predict_reshaped[:,:,0]))
    print('test_reshaped_B:', np.min(test_predict_reshaped[:,:,1]), np.max(test_predict_reshaped[:,:,1]))
    test_merged_LAB = np.dstack((BW_reshaped, test_predict_reshaped))
    test_merged_rgb = color.lab2rgb(test_merged_LAB)
    
    plt.figure(figsize=(15, 15))
    plt.imshow(test_merged_rgb)

# %%
get_photo(image_pathway)
# Out:
# Padded: 0.0 255.0
# PCA did not run
# 128
# 128
# (128, 128, 3)
# 0.0 255.0
# Padded: 0.0 255.0
# X_LAB: 21.73390280398273 100.0
# Y_LAB_org: -82.93441399808646 93.91007169334684
# Y_LAB: 0.17603744531997478 0.866836217552136
# (128, 128)
# image processed
# test_range: 0.47754723 0.5224528
# test_reshaped_A: -69.648895 73.22121
# test_reshaped_B: -73.221214 69.648895
